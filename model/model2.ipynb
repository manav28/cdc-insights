# %%
import os
import boto3

from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession

import sagemaker
from sagemaker import get_execution_role
import sagemaker_pyspark
from pyspark.sql.functions import *

role = get_execution_role()

# Configure Spark to use the SageMaker Spark dependency jars
jars = sagemaker_pyspark.classpath_jars()

classpath = ":".join(sagemaker_pyspark.classpath_jars())

# See the SageMaker Spark Github to learn how to connect to EMR from a notebook instance
spark = SparkSession.builder.config("spark.driver.extraClassPath", classpath)\
    .master("local[*]").getOrCreate()
    
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://172.16.168.179:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import os
import pandas as pd
import numpy as np
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession, SQLContext
from pyspark.sql.types import *
import pyspark.sql.functions as fn
from pyspark.sql.functions import col, udf
from pyspark.ml import Pipeline
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler
from pyspark.ml.regression import GeneralizedLinearRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.classification import RandomForestClassifier

# %%
cdc = spark.read.csv('output.csv', header = True)

# %%
cdc = cdc.drop('detail_age_type','detail_age', 'age_substitution_flag','age_recode_27', 'age_recode_12', 'infant_age_recode_22', 'icd_code_10th_revision')

# %%
cdc = cdc.drop('record_condition_20' , 'entity_condition_20', 'entity_condition_19', 'entity_condition_18', 'entity_condition_17', 'record_condition_19', 'record_condition_18', 'record_condition_16', 'record_condition_17','record_condition_15','record_condition_14','record_condition_13','record_condition_12','record_condition_11','record_condition_10','record_condition_9','record_condition_8','record_condition_7' , 'record_condition_6', 'record_condition_5', 'entity_condition_16', 'entity_condition_15','entity_condition_14', 'entity_condition_13', 'entity_condition_12', 'entity_condition_11', 'entity_condition_10', 'entity_condition_9','entity_condition_8', 'entity_condition_7', 'entity_condition_6', 'entity_condition_5')

# %%
cdc.printSchema()
# Out:
# root
#  |-- resident_status: string (nullable = true)
#  |-- education_1989_revision: string (nullable = true)
#  |-- education_2003_revision: string (nullable = true)
#  |-- education_reporting_flag: string (nullable = true)
#  |-- month_of_death: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- age_recode_52: string (nullable = true)
#  |-- place_of_death_and_decedents_status: string (nullable = true)
#  |-- marital_status: string (nullable = true)
#  |-- day_of_week_of_death: string (nullable = true)
#  |-- current_data_year: string (nullable = true)
#  |-- injury_at_work: string (nullable = true)
#  |-- manner_of_death: string (nullable = true)
#  |-- method_of_disposition: string (nullable = true)
#  |-- autopsy: string (nullable = true)
#  |-- activity_code: string (nullable = true)
#  |-- place_of_injury_for_causes_w00_y34_except_y06_and_y07_: string (nullable = true)
#  |-- 358_cause_recode: string (nullable = true)
#  |-- 113_cause_recode: string (nullable = true)
#  |-- 130_infant_cause_recode: string (nullable = true)
#  |-- 39_cause_recode: string (nullable = true)
#  |-- number_of_entity_axis_conditions: string (nullable = true)
#  |-- entity_condition_1: string (nullable = true)
#  |-- entity_condition_2: string (nullable = true)
#  |-- entity_condition_3: string (nullable = true)
#  |-- entity_condition_4: string (nullable = true)
#  |-- number_of_record_axis_conditions: string (nullable = true)
#  |-- record_condition_1: string (nullable = true)
#  |-- record_condition_2: string (nullable = true)
#  |-- record_condition_3: string (nullable = true)
#  |-- record_condition_4: string (nullable = true)
#  |-- race: string (nullable = true)
#  |-- bridged_race_flag: string (nullable = true)
#  |-- race_imputation_flag: string (nullable = true)
#  |-- race_recode_3: string (nullable = true)
#  |-- race_recode_5: string (nullable = true)
#  |-- hispanic_origin: string (nullable = true)
#  |-- hispanic_originrace_recode: string (nullable = true)

# %%
cdc = cdc.fillna({'place_of_injury_for_causes_w00_y34_except_y06_and_y07_' : '10'})
cdc = cdc.fillna({'130_infant_cause_recode' : '000'})
cdc = cdc.fillna({'activity_code' : '10'})
cdc = cdc.fillna({'manner_of_death' : '8'})
cdc = cdc.fillna({'Place_of_death_and_decedents_status': '7'})

# %%
cdc = cdc.withColumn('method_of_disposition', regexp_replace('method_of_disposition', 'R' , 'O'))
cdc = cdc.withColumn('method_of_disposition', regexp_replace('method_of_disposition', 'E' , 'O'))
cdc = cdc.withColumn('method_of_disposition', regexp_replace('method_of_disposition', 'D' , 'O'))
cdc = cdc.withColumn('method_of_disposition', regexp_replace('method_of_disposition', 'U' , 'O'))
cdc = cdc.withColumn('Place_of_death_and_decedents_status', regexp_replace('Place_of_death_and_decedents_status', '9' , '7'))

# %%
#cdc = cdc.withColumn('Place_of_death_and_decedents_status', 
 #                    when(cdc['Place_of_death_and_decedents_status']== 9 , 7).otherwise(cdc['Place_of_death_and_decedents_status']))

# %%
#cdc.select('Place_of_death_and_decedents_status').distinct().show()

# %%
#cdc.select('place_of_injury_for_causes_w00_y34_except_y06_and_y07_').distinct().show()

# %%
#cdc.select("education_1989_revision").distinct().show()

# %%
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '00' , '1'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '01' , '1'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '02' , '1'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '03' , '1'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '04' , '1'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '05' , '1'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '06' , '1'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '07' , '1'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '08' , '1'))

cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '09' , '2'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '10' , '2'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '11' , '2'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '12' , '3'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '13' , '4'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '14' , '4'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '15' , '5'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '16' , '6'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '17' , '7'))
cdc = cdc.withColumn('education_1989_revision', regexp_replace('education_1989_revision', '99' , '9'))

# %%
cdc = cdc.withColumn("education_2003_revision", coalesce(cdc.education_2003_revision,cdc.education_1989_revision))

# %%
cdc = cdc.filter(cdc.education_2003_revision.isNotNull())

# %%
#cdc.groupBy('education_2003_revision').count().orderBy('count', ascending=False).show()

# %%
#cdc.printSchema()

# %%
cdc = cdc.drop('education_1989_revision', 'education_reporting_flag','bridged_race_flag', 'race_imputation_flag', 
               'hispanic_origin','entity_condition_1','entity_condition_2','entity_condition_3','entity_condition_4',
              'record_condition_1','record_condition_2','record_condition_3','record_condition_4')

# %%
cdc = cdc.withColumn('number_of_entity_axis_conditions', cdc['number_of_entity_axis_conditions'].cast(DoubleType()))
cdc = cdc.withColumn('number_of_record_axis_conditions', cdc['number_of_record_axis_conditions'].cast(DoubleType()))

# %%
cdc = cdc.filter(cdc.method_of_disposition != 'O')

# %% [markdown]
# ### Building prediction model

# %%
cols = cdc.columns
categorical_cols = cols.copy()
categorical_cols.remove('number_of_entity_axis_conditions')
categorical_cols.remove('number_of_record_axis_conditions')
categorical_cols.remove('method_of_disposition')

# %%
categorical_cols
# Out:
# ['resident_status',
#  'education_2003_revision',
#  'month_of_death',
#  'sex',
#  'age_recode_52',
#  'Place_of_death_and_decedents_status',
#  'marital_status',
#  'day_of_week_of_death',
#  'current_data_year',
#  'injury_at_work',
#  'manner_of_death',
#  'autopsy',
#  'activity_code',
#  'place_of_injury_for_causes_w00_y34_except_y06_and_y07_',
#  '358_cause_recode',
#  '113_cause_recode',
#  '130_infant_cause_recode',
#  '39_cause_recode',
#  'race',
#  'race_recode_3',
#  'race_recode_5',
#  'hispanic_originrace_recode']

# %%
stages = []
for col in categorical_cols:
    string_indexer = StringIndexer(inputCol=col, outputCol=col + "Index")
    encoder = OneHotEncoder(inputCol=col + "Index", outputCol=col + "classVec")
    
    stages += [string_indexer, encoder]

# %%
label_string_index = StringIndexer(inputCol="method_of_disposition", outputCol="label")
stages += [label_string_index]

# %%
numeric_cols = ['number_of_entity_axis_conditions', 'number_of_record_axis_conditions']
assemblerInputs = [c + "classVec" for c in categorical_cols] + numeric_cols
assembler = VectorAssembler(inputCols=assemblerInputs, outputCol="features")
stages += [assembler]

# %%
partialPipeline = Pipeline().setStages(stages)
pipelineModel = partialPipeline.fit(cdc)
preppedDataDF = pipelineModel.transform(cdc)

# %%
selectedcols = ["label", "features"] + cols
dataset = preppedDataDF.select(selectedcols)
display(dataset)
# Out:
# DataFrame[label: double, features: vector, resident_status: string, education_2003_revision: string, month_of_death: string, sex: string, age_recode_52: string, Place_of_death_and_decedents_status: string, marital_status: string, day_of_week_of_death: string, current_data_year: string, injury_at_work: string, manner_of_death: string, method_of_disposition: string, autopsy: string, activity_code: string, place_of_injury_for_causes_w00_y34_except_y06_and_y07_: string, 358_cause_recode: string, 113_cause_recode: string, 130_infant_cause_recode: string, 39_cause_recode: string, number_of_entity_axis_conditions: double, number_of_record_axis_conditions: double, race: string, race_recode_3: string, race_recode_5: string, hispanic_originrace_recode: string]

# %%
(trainingData, testData) = dataset.randomSplit([0.7, 0.3], seed=100)

# %%
glr = GeneralizedLinearRegression(family="binomial", link="logit", maxIter=10, regParam=0.1)

# %%
lrModel = glr.fit(trainingData)

# %%
meta = [f.metadata 
    for f in preppedDataDF.schema.fields 
    if f.name == 'features'][0]
features_name_ind = meta['ml_attr']['attrs']['binary'] + meta['ml_attr']['attrs']['numeric']
features_name_ind
# Out:
# [{'idx': 0, 'name': 'resident_statusclassVec_1'},
#  {'idx': 1, 'name': 'resident_statusclassVec_2'},
#  {'idx': 2, 'name': 'resident_statusclassVec_3'},
#  {'idx': 3, 'name': 'education_2003_revisionclassVec_3'},
#  {'idx': 4, 'name': 'education_2003_revisionclassVec_1'},
#  {'idx': 5, 'name': 'education_2003_revisionclassVec_4'},
#  {'idx': 6, 'name': 'education_2003_revisionclassVec_2'},
#  {'idx': 7, 'name': 'education_2003_revisionclassVec_6'},
#  {'idx': 8, 'name': 'education_2003_revisionclassVec_5'},
#  {'idx': 9, 'name': 'education_2003_revisionclassVec_7'},
#  {'idx': 10, 'name': 'education_2003_revisionclassVec_9'},
#  {'idx': 11, 'name': 'month_of_deathclassVec_01'},
#  {'idx': 12, 'name': 'month_of_deathclassVec_12'},
#  {'idx': 13, 'name': 'month_of_deathclassVec_03'},
#  {'idx': 14, 'name': 'month_of_deathclassVec_11'},
#  {'idx': 15, 'name': 'month_of_deathclassVec_10'},
#  {'idx': 16, 'name': 'month_of_deathclassVec_02'},
#  {'idx': 17, 'name': 'month_of_deathclassVec_04'},
#  {'idx': 18, 'name': 'month_of_deathclassVec_05'},
#  {'idx': 19, 'name': 'month_of_deathclassVec_07'},
#  {'idx': 20, 'name': 'month_of_deathclassVec_08'},
#  {'idx': 21, 'name': 'month_of_deathclassVec_09'},
#  {'idx': 22, 'name': 'sexclassVec_M'},
#  {'idx': 23, 'name': 'age_recode_52classVec_43'},
#  {'idx': 24, 'name': 'age_recode_52classVec_42'},
#  {'idx': 25, 'name': 'age_recode_52classVec_41'},
#  {'idx': 26, 'name': 'age_recode_52classVec_44'},
#  {'idx': 27, 'name': 'age_recode_52classVec_40'},
#  {'idx': 28, 'name': 'age_recode_52classVec_39'},
#  {'idx': 29, 'name': 'age_recode_52classVec_38'},
#  {'idx': 30, 'name': 'age_recode_52classVec_37'},
#  {'idx': 31, 'name': 'age_recode_52classVec_36'},
#  {'idx': 32, 'name': 'age_recode_52classVec_45'},
#  {'idx': 33, 'name': 'age_recode_52classVec_35'},
#  {'idx': 34, 'name': 'age_recode_52classVec_34'},
#  {'idx': 35, 'name': 'age_recode_52classVec_33'},
#  {'idx': 36, 'name': 'age_recode_52classVec_32'},
#  {'idx': 37, 'name': 'age_recode_52classVec_46'},
#  {'idx': 38, 'name': 'age_recode_52classVec_31'},
#  {'idx': 39, 'name': 'age_recode_52classVec_30'},
#  {'idx': 40, 'name': 'age_recode_52classVec_29'},
#  {'idx': 41, 'name': 'age_recode_52classVec_02'},
#  {'idx': 42, 'name': 'age_recode_52classVec_01'},
#  {'idx': 43, 'name': 'age_recode_52classVec_28'},
#  {'idx': 44, 'name': 'age_recode_52classVec_27'},
#  {'idx': 45, 'name': 'age_recode_52classVec_12'},
#  {'idx': 46, 'name': 'age_recode_52classVec_23'},
#  {'idx': 47, 'name': 'age_recode_52classVec_47'},
#  {'idx': 48, 'name': 'age_recode_52classVec_13'},
#  {'idx': 49, 'name': 'age_recode_52classVec_09'},
#  {'idx': 50, 'name': 'age_recode_52classVec_14'},
#  {'idx': 51, 'name': 'age_recode_52classVec_24'},
#  {'idx': 52, 'name': 'age_recode_52classVec_03'},
#  {'idx': 53, 'name': 'age_recode_52classVec_10'},
#  {'idx': 54, 'name': 'age_recode_52classVec_15'},
#  {'idx': 55, 'name': 'age_recode_52classVec_25'},
#  {'idx': 56, 'name': 'age_recode_52classVec_04'},
#  {'idx': 57, 'name': 'age_recode_52classVec_11'},
#  {'idx': 58, 'name': 'age_recode_52classVec_26'},
#  {'idx': 59, 'name': 'age_recode_52classVec_16'},
#  {'idx': 60, 'name': 'age_recode_52classVec_17'},
#  {'idx': 61, 'name': 'age_recode_52classVec_05'},
#  {'idx': 62, 'name': 'age_recode_52classVec_18'},
#  {'idx': 63, 'name': 'age_recode_52classVec_06'},
#  {'idx': 64, 'name': 'age_recode_52classVec_07'},
#  {'idx': 65, 'name': 'age_recode_52classVec_19'},
#  {'idx': 66, 'name': 'age_recode_52classVec_08'},
#  {'idx': 67, 'name': 'age_recode_52classVec_20'},
#  {'idx': 68, 'name': 'age_recode_52classVec_52'},
#  {'idx': 69, 'name': 'age_recode_52classVec_22'},
#  {'idx': 70, 'name': 'age_recode_52classVec_21'},
#  {'idx': 71, 'name': 'age_recode_52classVec_48'},
#  {'idx': 72, 'name': 'age_recode_52classVec_49'},
#  {'idx': 73, 'name': 'age_recode_52classVec_50'},
#  {'idx': 74, 'name': 'Place_of_death_and_decedents_statusclassVec_1'},
#  {'idx': 75, 'name': 'Place_of_death_and_decedents_statusclassVec_4'},
#  {'idx': 76, 'name': 'Place_of_death_and_decedents_statusclassVec_6'},
#  {'idx': 77, 'name': 'Place_of_death_and_decedents_statusclassVec_2'},
#  {'idx': 78, 'name': 'Place_of_death_and_decedents_statusclassVec_5'},
#  {'idx': 79, 'name': 'Place_of_death_and_decedents_statusclassVec_7'},
#  {'idx': 80, 'name': 'marital_statusclassVec_M'},
#  {'idx': 81, 'name': 'marital_statusclassVec_W'},
#  {'idx': 82, 'name': 'marital_statusclassVec_D'},
#  {'idx': 83, 'name': 'marital_statusclassVec_S'},
#  {'idx': 84, 'name': 'day_of_week_of_deathclassVec_7'},
#  {'idx': 85, 'name': 'day_of_week_of_deathclassVec_6'},
#  {'idx': 86, 'name': 'day_of_week_of_deathclassVec_2'},
#  {'idx': 87, 'name': 'day_of_week_of_deathclassVec_5'},
#  {'idx': 88, 'name': 'day_of_week_of_deathclassVec_4'},
#  {'idx': 89, 'name': 'day_of_week_of_deathclassVec_3'},
#  {'idx': 90, 'name': 'day_of_week_of_deathclassVec_1'},
#  {'idx': 91, 'name': 'current_data_yearclassVec_2015'},
#  {'idx': 92, 'name': 'current_data_yearclassVec_2014'},
#  {'idx': 93, 'name': 'current_data_yearclassVec_2013'},
#  {'idx': 94, 'name': 'current_data_yearclassVec_2012'},
#  {'idx': 95, 'name': 'current_data_yearclassVec_2011'},
#  {'idx': 96, 'name': 'current_data_yearclassVec_2010'},
#  {'idx': 97, 'name': 'current_data_yearclassVec_2008'},
#  {'idx': 98, 'name': 'current_data_yearclassVec_2009'},
#  {'idx': 99, 'name': 'current_data_yearclassVec_2007'},
#  {'idx': 100, 'name': 'current_data_yearclassVec_2006'},
#  {'idx': 101, 'name': 'injury_at_workclassVec_U'},
#  {'idx': 102, 'name': 'injury_at_workclassVec_N'},
#  {'idx': 103, 'name': 'manner_of_deathclassVec_7'},
#  {'idx': 104, 'name': 'manner_of_deathclassVec_8'},
#  {'idx': 105, 'name': 'manner_of_deathclassVec_1'},
#  {'idx': 106, 'name': 'manner_of_deathclassVec_2'},
#  {'idx': 107, 'name': 'manner_of_deathclassVec_3'},
#  {'idx': 108, 'name': 'manner_of_deathclassVec_5'},
#  {'idx': 109, 'name': 'autopsyclassVec_N'},
#  {'idx': 110, 'name': 'autopsyclassVec_Y'},
#  {'idx': 111, 'name': 'autopsyclassVec_U'},
#  {'idx': 112, 'name': 'autopsyclassVec_n'},
#  {'idx': 113, 'name': 'activity_codeclassVec_10'},
#  {'idx': 114, 'name': 'activity_codeclassVec_9'},
#  {'idx': 115, 'name': 'activity_codeclassVec_4'},
#  {'idx': 116, 'name': 'activity_codeclassVec_2'},
#  {'idx': 117, 'name': 'activity_codeclassVec_0'},
#  {'idx': 118, 'name': 'activity_codeclassVec_8'},
#  {'idx': 119, 'name': 'activity_codeclassVec_1'},
#  {'idx': 120,
#   'name': 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_10'},
#  {'idx': 121,
#   'name': 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_0'},
#  {'idx': 122,
#   'name': 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_9'},
#  {'idx': 123,
#   'name': 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_8'},
#  {'idx': 124,
#   'name': 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_1'},
#  {'idx': 125,
#   'name': 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_4'},
#  {'idx': 126,
#   'name': 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_5'},
#  {'idx': 127,
#   'name': 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_2'},
#  {'idx': 128,
#   'name': 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_6'},
#  {'idx': 129,
#   'name': 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_7'},
#  {'idx': 130, 'name': '358_cause_recodeclassVec_215'},
#  {'idx': 131, 'name': '358_cause_recodeclassVec_093'},
#  {'idx': 132, 'name': '358_cause_recodeclassVec_267'},
#  {'idx': 133, 'name': '358_cause_recodeclassVec_211'},
#  {'idx': 134, 'name': '358_cause_recodeclassVec_175'},
#  {'idx': 135, 'name': '358_cause_recodeclassVec_189'},
#  {'idx': 136, 'name': '358_cause_recodeclassVec_159'},
#  {'idx': 137, 'name': '358_cause_recodeclassVec_238'},
#  {'idx': 138, 'name': '358_cause_recodeclassVec_214'},
#  {'idx': 139, 'name': '358_cause_recodeclassVec_230'},
#  {'idx': 140, 'name': '358_cause_recodeclassVec_257'},
#  {'idx': 141, 'name': '358_cause_recodeclassVec_081'},
#  {'idx': 142, 'name': '358_cause_recodeclassVec_327'},
#  {'idx': 143, 'name': '358_cause_recodeclassVec_104'},
#  {'idx': 144, 'name': '358_cause_recodeclassVec_228'},
#  {'idx': 145, 'name': '358_cause_recodeclassVec_125'},
#  {'idx': 146, 'name': '358_cause_recodeclassVec_088'},
#  {'idx': 147, 'name': '358_cause_recodeclassVec_207'},
#  {'idx': 148, 'name': '358_cause_recodeclassVec_420'},
#  {'idx': 149, 'name': '358_cause_recodeclassVec_023'},
#  {'idx': 150, 'name': '358_cause_recodeclassVec_194'},
#  {'idx': 151, 'name': '358_cause_recodeclassVec_278'},
#  {'idx': 152, 'name': '358_cause_recodeclassVec_113'},
#  {'idx': 153, 'name': '358_cause_recodeclassVec_236'},
#  {'idx': 154, 'name': '358_cause_recodeclassVec_239'},
#  {'idx': 155, 'name': '358_cause_recodeclassVec_227'},
#  {'idx': 156, 'name': '358_cause_recodeclassVec_188'},
#  {'idx': 157, 'name': '358_cause_recodeclassVec_129'},
#  {'idx': 158, 'name': '358_cause_recodeclassVec_429'},
#  {'idx': 159, 'name': '358_cause_recodeclassVec_298'},
#  {'idx': 160, 'name': '358_cause_recodeclassVec_206'},
#  {'idx': 161, 'name': '358_cause_recodeclassVec_085'},
#  {'idx': 162, 'name': '358_cause_recodeclassVec_397'},
#  {'idx': 163, 'name': '358_cause_recodeclassVec_273'},
#  {'idx': 164, 'name': '358_cause_recodeclassVec_300'},
#  {'idx': 165, 'name': '358_cause_recodeclassVec_225'},
#  {'idx': 166, 'name': '358_cause_recodeclassVec_118'},
#  {'idx': 167, 'name': '358_cause_recodeclassVec_380'},
#  {'idx': 168, 'name': '358_cause_recodeclassVec_233'},
#  {'idx': 169, 'name': '358_cause_recodeclassVec_122'},
#  {'idx': 170, 'name': '358_cause_recodeclassVec_109'},
#  {'idx': 171, 'name': '358_cause_recodeclassVec_077'},
#  {'idx': 172, 'name': '358_cause_recodeclassVec_293'},
#  {'idx': 173, 'name': '358_cause_recodeclassVec_173'},
#  {'idx': 174, 'name': '358_cause_recodeclassVec_117'},
#  {'idx': 175, 'name': '358_cause_recodeclassVec_145'},
#  {'idx': 176, 'name': '358_cause_recodeclassVec_379'},
#  {'idx': 177, 'name': '358_cause_recodeclassVec_406'},
#  {'idx': 178, 'name': '358_cause_recodeclassVec_435'},
#  {'idx': 179, 'name': '358_cause_recodeclassVec_330'},
#  {'idx': 180, 'name': '358_cause_recodeclassVec_078'},
#  {'idx': 181, 'name': '358_cause_recodeclassVec_132'},
#  {'idx': 182, 'name': '358_cause_recodeclassVec_135'},
#  {'idx': 183, 'name': '358_cause_recodeclassVec_404'},
#  {'idx': 184, 'name': '358_cause_recodeclassVec_301'},
#  {'idx': 185, 'name': '358_cause_recodeclassVec_242'},
#  {'idx': 186, 'name': '358_cause_recodeclassVec_208'},
#  {'idx': 187, 'name': '358_cause_recodeclassVec_428'},
#  {'idx': 188, 'name': '358_cause_recodeclassVec_266'},
#  {'idx': 189, 'name': '358_cause_recodeclassVec_423'},
#  {'idx': 190, 'name': '358_cause_recodeclassVec_082'},
#  {'idx': 191, 'name': '358_cause_recodeclassVec_098'},
#  {'idx': 192, 'name': '358_cause_recodeclassVec_243'},
#  {'idx': 193, 'name': '358_cause_recodeclassVec_108'},
#  {'idx': 194, 'name': '358_cause_recodeclassVec_047'},
#  {'idx': 195, 'name': '358_cause_recodeclassVec_306'},
#  {'idx': 196, 'name': '358_cause_recodeclassVec_010'},
#  {'idx': 197, 'name': '358_cause_recodeclassVec_178'},
#  {'idx': 198, 'name': '358_cause_recodeclassVec_241'},
#  {'idx': 199, 'name': '358_cause_recodeclassVec_218'},
#  {'idx': 200, 'name': '358_cause_recodeclassVec_237'},
#  {'idx': 201, 'name': '358_cause_recodeclassVec_219'},
#  {'idx': 202, 'name': '358_cause_recodeclassVec_134'},
#  {'idx': 203, 'name': '358_cause_recodeclassVec_169'},
#  {'idx': 204, 'name': '358_cause_recodeclassVec_231'},
#  {'idx': 205, 'name': '358_cause_recodeclassVec_376'},
#  {'idx': 206, 'name': '358_cause_recodeclassVec_393'},
#  {'idx': 207, 'name': '358_cause_recodeclassVec_172'},
#  {'idx': 208, 'name': '358_cause_recodeclassVec_235'},
#  {'idx': 209, 'name': '358_cause_recodeclassVec_425'},
#  {'idx': 210, 'name': '358_cause_recodeclassVec_226'},
#  {'idx': 211, 'name': '358_cause_recodeclassVec_103'},
#  {'idx': 212, 'name': '358_cause_recodeclassVec_086'},
#  {'idx': 213, 'name': '358_cause_recodeclassVec_137'},
#  {'idx': 214, 'name': '358_cause_recodeclassVec_295'},
#  {'idx': 215, 'name': '358_cause_recodeclassVec_388'},
#  {'idx': 216, 'name': '358_cause_recodeclassVec_410'},
#  {'idx': 217, 'name': '358_cause_recodeclassVec_313'},
#  {'idx': 218, 'name': '358_cause_recodeclassVec_107'},
#  {'idx': 219, 'name': '358_cause_recodeclassVec_358'},
#  {'idx': 220, 'name': '358_cause_recodeclassVec_212'},
#  {'idx': 221, 'name': '358_cause_recodeclassVec_209'},
#  {'idx': 222, 'name': '358_cause_recodeclassVec_190'},
#  {'idx': 223, 'name': '358_cause_recodeclassVec_092'},
#  {'idx': 224, 'name': '358_cause_recodeclassVec_087'},
#  {'idx': 225, 'name': '358_cause_recodeclassVec_268'},
#  {'idx': 226, 'name': '358_cause_recodeclassVec_256'},
#  {'idx': 227, 'name': '358_cause_recodeclassVec_409'},
#  {'idx': 228, 'name': '358_cause_recodeclassVec_049'},
#  {'idx': 229, 'name': '358_cause_recodeclassVec_405'},
#  {'idx': 230, 'name': '358_cause_recodeclassVec_074'},
#  {'idx': 231, 'name': '358_cause_recodeclassVec_302'},
#  {'idx': 232, 'name': '358_cause_recodeclassVec_245'},
#  {'idx': 233, 'name': '358_cause_recodeclassVec_304'},
#  {'idx': 234, 'name': '358_cause_recodeclassVec_099'},
#  {'idx': 235, 'name': '358_cause_recodeclassVec_167'},
#  {'idx': 236, 'name': '358_cause_recodeclassVec_179'},
#  {'idx': 237, 'name': '358_cause_recodeclassVec_075'},
#  {'idx': 238, 'name': '358_cause_recodeclassVec_372'},
#  {'idx': 239, 'name': '358_cause_recodeclassVec_357'},
#  {'idx': 240, 'name': '358_cause_recodeclassVec_294'},
#  {'idx': 241, 'name': '358_cause_recodeclassVec_364'},
#  {'idx': 242, 'name': '358_cause_recodeclassVec_386'},
#  {'idx': 243, 'name': '358_cause_recodeclassVec_152'},
#  {'idx': 244, 'name': '358_cause_recodeclassVec_369'},
#  {'idx': 245, 'name': '358_cause_recodeclassVec_414'},
#  {'idx': 246, 'name': '358_cause_recodeclassVec_153'},
#  {'idx': 247, 'name': '358_cause_recodeclassVec_443'},
#  {'idx': 248, 'name': '358_cause_recodeclassVec_101'},
#  {'idx': 249, 'name': '358_cause_recodeclassVec_392'},
#  {'idx': 250, 'name': '358_cause_recodeclassVec_124'},
#  {'idx': 251, 'name': '358_cause_recodeclassVec_441'},
#  {'idx': 252, 'name': '358_cause_recodeclassVec_253'},
#  {'idx': 253, 'name': '358_cause_recodeclassVec_395'},
#  {'idx': 254, 'name': '358_cause_recodeclassVec_224'},
#  {'idx': 255, 'name': '358_cause_recodeclassVec_311'},
#  {'idx': 256, 'name': '358_cause_recodeclassVec_431'},
#  {'idx': 257, 'name': '358_cause_recodeclassVec_053'},
#  {'idx': 258, 'name': '358_cause_recodeclassVec_073'},
#  {'idx': 259, 'name': '358_cause_recodeclassVec_331'},
#  {'idx': 260, 'name': '358_cause_recodeclassVec_421'},
#  {'idx': 261, 'name': '358_cause_recodeclassVec_308'},
#  {'idx': 262, 'name': '358_cause_recodeclassVec_309'},
#  {'idx': 263, 'name': '358_cause_recodeclassVec_282'},
#  {'idx': 264, 'name': '358_cause_recodeclassVec_456'},
#  {'idx': 265, 'name': '358_cause_recodeclassVec_011'},
#  {'idx': 266, 'name': '358_cause_recodeclassVec_291'},
#  {'idx': 267, 'name': '358_cause_recodeclassVec_191'},
#  {'idx': 268, 'name': '358_cause_recodeclassVec_378'},
#  {'idx': 269, 'name': '358_cause_recodeclassVec_158'},
#  {'idx': 270, 'name': '358_cause_recodeclassVec_296'},
#  {'idx': 271, 'name': '358_cause_recodeclassVec_436'},
#  {'idx': 272, 'name': '358_cause_recodeclassVec_024'},
#  {'idx': 273, 'name': '358_cause_recodeclassVec_052'},
#  {'idx': 274, 'name': '358_cause_recodeclassVec_318'},
#  {'idx': 275, 'name': '358_cause_recodeclassVec_325'},
#  {'idx': 276, 'name': '358_cause_recodeclassVec_411'},
#  {'idx': 277, 'name': '358_cause_recodeclassVec_305'},
#  {'idx': 278, 'name': '358_cause_recodeclassVec_193'},
#  {'idx': 279, 'name': '358_cause_recodeclassVec_315'},
#  {'idx': 280, 'name': '358_cause_recodeclassVec_201'},
#  {'idx': 281, 'name': '358_cause_recodeclassVec_089'},
#  {'idx': 282, 'name': '358_cause_recodeclassVec_155'},
#  {'idx': 283, 'name': '358_cause_recodeclassVec_096'},
#  {'idx': 284, 'name': '358_cause_recodeclassVec_106'},
#  {'idx': 285, 'name': '358_cause_recodeclassVec_448'},
#  {'idx': 286, 'name': '358_cause_recodeclassVec_176'},
#  {'idx': 287, 'name': '358_cause_recodeclassVec_314'},
#  {'idx': 288, 'name': '358_cause_recodeclassVec_079'},
#  {'idx': 289, 'name': '358_cause_recodeclassVec_221'},
#  {'idx': 290, 'name': '358_cause_recodeclassVec_312'},
#  {'idx': 291, 'name': '358_cause_recodeclassVec_285'},
#  {'idx': 292, 'name': '358_cause_recodeclassVec_127'},
#  {'idx': 293, 'name': '358_cause_recodeclassVec_326'},
#  {'idx': 294, 'name': '358_cause_recodeclassVec_068'},
#  {'idx': 295, 'name': '358_cause_recodeclassVec_317'},
#  {'idx': 296, 'name': '358_cause_recodeclassVec_427'},
#  {'idx': 297, 'name': '358_cause_recodeclassVec_054'},
#  {'idx': 298, 'name': '358_cause_recodeclassVec_051'},
#  {'idx': 299, 'name': '358_cause_recodeclassVec_374'},
#  {'idx': 300, 'name': '358_cause_recodeclassVec_246'},
#  {'idx': 301, 'name': '358_cause_recodeclassVec_277'},
#  {'idx': 302, 'name': '358_cause_recodeclassVec_373'},
#  {'idx': 303, 'name': '358_cause_recodeclassVec_396'},
#  {'idx': 304, 'name': '358_cause_recodeclassVec_284'},
#  {'idx': 305, 'name': '358_cause_recodeclassVec_146'},
#  {'idx': 306, 'name': '358_cause_recodeclassVec_056'},
#  {'idx': 307, 'name': '358_cause_recodeclassVec_269'},
#  {'idx': 308, 'name': '358_cause_recodeclassVec_430'},
#  {'idx': 309, 'name': '358_cause_recodeclassVec_292'},
#  {'idx': 310, 'name': '358_cause_recodeclassVec_286'},
#  {'idx': 311, 'name': '358_cause_recodeclassVec_362'},
#  {'idx': 312, 'name': '358_cause_recodeclassVec_151'},
#  {'idx': 313, 'name': '358_cause_recodeclassVec_154'},
#  {'idx': 314, 'name': '358_cause_recodeclassVec_143'},
#  {'idx': 315, 'name': '358_cause_recodeclassVec_204'},
#  {'idx': 316, 'name': '358_cause_recodeclassVec_368'},
#  {'idx': 317, 'name': '358_cause_recodeclassVec_083'},
#  {'idx': 318, 'name': '358_cause_recodeclassVec_222'},
#  {'idx': 319, 'name': '358_cause_recodeclassVec_363'},
#  {'idx': 320, 'name': '358_cause_recodeclassVec_150'},
#  {'idx': 321, 'name': '358_cause_recodeclassVec_119'},
#  {'idx': 322, 'name': '358_cause_recodeclassVec_402'},
#  {'idx': 323, 'name': '358_cause_recodeclassVec_050'},
#  {'idx': 324, 'name': '358_cause_recodeclassVec_203'},
#  {'idx': 325, 'name': '358_cause_recodeclassVec_276'},
#  {'idx': 326, 'name': '358_cause_recodeclassVec_187'},
#  {'idx': 327, 'name': '358_cause_recodeclassVec_422'},
#  {'idx': 328, 'name': '358_cause_recodeclassVec_387'},
#  {'idx': 329, 'name': '358_cause_recodeclassVec_399'},
#  {'idx': 330, 'name': '358_cause_recodeclassVec_181'},
#  {'idx': 331, 'name': '358_cause_recodeclassVec_232'},
#  {'idx': 332, 'name': '358_cause_recodeclassVec_271'},
#  {'idx': 333, 'name': '358_cause_recodeclassVec_289'},
#  {'idx': 334, 'name': '358_cause_recodeclassVec_370'},
#  {'idx': 335, 'name': '358_cause_recodeclassVec_186'},
#  {'idx': 336, 'name': '358_cause_recodeclassVec_361'},
#  {'idx': 337, 'name': '358_cause_recodeclassVec_333'},
#  {'idx': 338, 'name': '358_cause_recodeclassVec_434'},
#  {'idx': 339, 'name': '358_cause_recodeclassVec_407'},
#  {'idx': 340, 'name': '358_cause_recodeclassVec_163'},
#  {'idx': 341, 'name': '358_cause_recodeclassVec_144'},
#  {'idx': 342, 'name': '358_cause_recodeclassVec_110'},
#  {'idx': 343, 'name': '358_cause_recodeclassVec_183'},
#  {'idx': 344, 'name': '358_cause_recodeclassVec_094'},
#  {'idx': 345, 'name': '358_cause_recodeclassVec_180'},
#  {'idx': 346, 'name': '358_cause_recodeclassVec_261'},
#  {'idx': 347, 'name': '358_cause_recodeclassVec_401'},
#  {'idx': 348, 'name': '358_cause_recodeclassVec_091'},
#  {'idx': 349, 'name': '358_cause_recodeclassVec_171'},
#  {'idx': 350, 'name': '358_cause_recodeclassVec_451'},
#  {'idx': 351, 'name': '358_cause_recodeclassVec_384'},
#  {'idx': 352, 'name': '358_cause_recodeclassVec_184'},
#  {'idx': 353, 'name': '358_cause_recodeclassVec_013'},
#  {'idx': 354, 'name': '358_cause_recodeclassVec_371'},
#  {'idx': 355, 'name': '358_cause_recodeclassVec_400'},
#  {'idx': 356, 'name': '358_cause_recodeclassVec_328'},
#  {'idx': 357, 'name': '358_cause_recodeclassVec_290'},
#  {'idx': 358, 'name': '358_cause_recodeclassVec_454'},
#  {'idx': 359, 'name': '358_cause_recodeclassVec_114'},
#  {'idx': 360, 'name': '358_cause_recodeclassVec_360'},
#  {'idx': 361, 'name': '358_cause_recodeclassVec_264'},
#  {'idx': 362, 'name': '358_cause_recodeclassVec_366'},
#  {'idx': 363, 'name': '358_cause_recodeclassVec_115'},
#  {'idx': 364, 'name': '358_cause_recodeclassVec_352'},
#  {'idx': 365, 'name': '358_cause_recodeclassVec_265'},
#  {'idx': 366, 'name': '358_cause_recodeclassVec_131'},
#  {'idx': 367, 'name': '358_cause_recodeclassVec_120'},
#  {'idx': 368, 'name': '358_cause_recodeclassVec_149'},
#  {'idx': 369, 'name': '358_cause_recodeclassVec_288'},
#  {'idx': 370, 'name': '358_cause_recodeclassVec_412'},
#  {'idx': 371, 'name': '358_cause_recodeclassVec_161'},
#  {'idx': 372, 'name': '358_cause_recodeclassVec_354'},
#  {'idx': 373, 'name': '358_cause_recodeclassVec_426'},
#  {'idx': 374, 'name': '358_cause_recodeclassVec_255'},
#  {'idx': 375, 'name': '358_cause_recodeclassVec_280'},
#  {'idx': 376, 'name': '358_cause_recodeclassVec_338'},
#  {'idx': 377, 'name': '358_cause_recodeclassVec_355'},
#  {'idx': 378, 'name': '358_cause_recodeclassVec_334'},
#  {'idx': 379, 'name': '358_cause_recodeclassVec_067'},
#  {'idx': 380, 'name': '358_cause_recodeclassVec_123'},
#  {'idx': 381, 'name': '358_cause_recodeclassVec_446'},
#  {'idx': 382, 'name': '358_cause_recodeclassVec_259'},
#  {'idx': 383, 'name': '358_cause_recodeclassVec_042'},
#  {'idx': 384, 'name': '358_cause_recodeclassVec_160'},
#  {'idx': 385, 'name': '358_cause_recodeclassVec_440'},
#  {'idx': 386, 'name': '358_cause_recodeclassVec_323'},
#  {'idx': 387, 'name': '358_cause_recodeclassVec_168'},
#  {'idx': 388, 'name': '358_cause_recodeclassVec_367'},
#  {'idx': 389, 'name': '358_cause_recodeclassVec_043'},
#  {'idx': 390, 'name': '358_cause_recodeclassVec_192'},
#  {'idx': 391, 'name': '358_cause_recodeclassVec_014'},
#  {'idx': 392, 'name': '358_cause_recodeclassVec_394'},
#  {'idx': 393, 'name': '358_cause_recodeclassVec_251'},
#  {'idx': 394, 'name': '358_cause_recodeclassVec_182'},
#  {'idx': 395, 'name': '358_cause_recodeclassVec_061'},
#  {'idx': 396, 'name': '358_cause_recodeclassVec_337'},
#  {'idx': 397, 'name': '358_cause_recodeclassVec_136'},
#  {'idx': 398, 'name': '358_cause_recodeclassVec_455'},
#  {'idx': 399, 'name': '358_cause_recodeclassVec_418'},
#  {'idx': 400, 'name': '358_cause_recodeclassVec_041'},
#  {'idx': 401, 'name': '358_cause_recodeclassVec_408'},
#  {'idx': 402, 'name': '358_cause_recodeclassVec_275'},
#  {'idx': 403, 'name': '358_cause_recodeclassVec_391'},
#  {'idx': 404, 'name': '358_cause_recodeclassVec_324'},
#  {'idx': 405, 'name': '358_cause_recodeclassVec_433'},
#  {'idx': 406, 'name': '358_cause_recodeclassVec_444'},
#  {'idx': 407, 'name': '358_cause_recodeclassVec_299'},
#  {'idx': 408, 'name': '358_cause_recodeclassVec_445'},
#  {'idx': 409, 'name': '358_cause_recodeclassVec_202'},
#  {'idx': 410, 'name': '358_cause_recodeclassVec_022'},
#  {'idx': 411, 'name': '358_cause_recodeclassVec_130'},
#  {'idx': 412, 'name': '358_cause_recodeclassVec_329'},
#  {'idx': 413, 'name': '358_cause_recodeclassVec_415'},
#  {'idx': 414, 'name': '358_cause_recodeclassVec_072'},
#  {'idx': 415, 'name': '358_cause_recodeclassVec_447'},
#  {'idx': 416, 'name': '358_cause_recodeclassVec_196'},
#  {'idx': 417, 'name': '358_cause_recodeclassVec_437'},
#  {'idx': 418, 'name': '358_cause_recodeclassVec_438'},
#  {'idx': 419, 'name': '358_cause_recodeclassVec_335'},
#  {'idx': 420, 'name': '358_cause_recodeclassVec_351'},
#  {'idx': 421, 'name': '358_cause_recodeclassVec_166'},
#  {'idx': 422, 'name': '358_cause_recodeclassVec_347'},
#  {'idx': 423, 'name': '358_cause_recodeclassVec_102'},
#  {'idx': 424, 'name': '358_cause_recodeclassVec_260'},
#  {'idx': 425, 'name': '358_cause_recodeclassVec_095'},
#  {'idx': 426, 'name': '358_cause_recodeclassVec_142'},
#  {'idx': 427, 'name': '358_cause_recodeclassVec_195'},
#  {'idx': 428, 'name': '358_cause_recodeclassVec_066'},
#  {'idx': 429, 'name': '358_cause_recodeclassVec_450'},
#  {'idx': 430, 'name': '358_cause_recodeclassVec_350'},
#  {'idx': 431, 'name': '358_cause_recodeclassVec_140'},
#  {'idx': 432, 'name': '358_cause_recodeclassVec_006'},
#  {'idx': 433, 'name': '358_cause_recodeclassVec_353'},
#  {'idx': 434, 'name': '358_cause_recodeclassVec_348'},
#  {'idx': 435, 'name': '358_cause_recodeclassVec_417'},
#  {'idx': 436, 'name': '358_cause_recodeclassVec_287'},
#  {'idx': 437, 'name': '358_cause_recodeclassVec_199'},
#  {'idx': 438, 'name': '358_cause_recodeclassVec_028'},
#  {'idx': 439, 'name': '358_cause_recodeclassVec_416'},
#  {'idx': 440, 'name': '358_cause_recodeclassVec_250'},
#  {'idx': 441, 'name': '358_cause_recodeclassVec_065'},
#  {'idx': 442, 'name': '358_cause_recodeclassVec_359'},
#  {'idx': 443, 'name': '358_cause_recodeclassVec_249'},
#  {'idx': 444, 'name': '358_cause_recodeclassVec_062'},
#  {'idx': 445, 'name': '358_cause_recodeclassVec_111'},
#  {'idx': 446, 'name': '358_cause_recodeclassVec_020'},
#  {'idx': 447, 'name': '358_cause_recodeclassVec_341'},
#  {'idx': 448, 'name': '358_cause_recodeclassVec_452'},
#  {'idx': 449, 'name': '358_cause_recodeclassVec_035'},
#  {'idx': 450, 'name': '358_cause_recodeclassVec_139'},
#  {'idx': 451, 'name': '358_cause_recodeclassVec_029'},
#  {'idx': 452, 'name': '358_cause_recodeclassVec_033'},
#  {'idx': 453, 'name': '358_cause_recodeclassVec_058'},
#  {'idx': 454, 'name': '358_cause_recodeclassVec_345'},
#  {'idx': 455, 'name': '358_cause_recodeclassVec_390'},
#  {'idx': 456, 'name': '358_cause_recodeclassVec_342'},
#  {'idx': 457, 'name': '358_cause_recodeclassVec_008'},
#  {'idx': 458, 'name': '358_cause_recodeclassVec_274'},
#  {'idx': 459, 'name': '358_cause_recodeclassVec_039'},
#  {'idx': 460, 'name': '358_cause_recodeclassVec_060'},
#  {'idx': 461, 'name': '358_cause_recodeclassVec_031'},
#  {'idx': 462, 'name': '358_cause_recodeclassVec_018'},
#  {'idx': 463, 'name': '358_cause_recodeclassVec_030'},
#  {'idx': 464, 'name': '358_cause_recodeclassVec_009'},
#  {'idx': 465, 'name': '358_cause_recodeclassVec_007'},
#  {'idx': 466, 'name': '358_cause_recodeclassVec_027'},
#  {'idx': 467, 'name': '358_cause_recodeclassVec_162'},
#  {'idx': 468, 'name': '358_cause_recodeclassVec_021'},
#  {'idx': 469, 'name': '358_cause_recodeclassVec_398'},
#  {'idx': 470, 'name': '358_cause_recodeclassVec_439'},
#  {'idx': 471, 'name': '358_cause_recodeclassVec_343'},
#  {'idx': 472, 'name': '358_cause_recodeclassVec_038'},
#  {'idx': 473, 'name': '358_cause_recodeclassVec_344'},
#  {'idx': 474, 'name': '358_cause_recodeclassVec_017'},
#  {'idx': 475, 'name': '358_cause_recodeclassVec_016'},
#  {'idx': 476, 'name': '358_cause_recodeclassVec_064'},
#  {'idx': 477, 'name': '358_cause_recodeclassVec_034'},
#  {'idx': 478, 'name': '358_cause_recodeclassVec_046'},
#  {'idx': 479, 'name': '358_cause_recodeclassVec_059'},
#  {'idx': 480, 'name': '358_cause_recodeclassVec_045'},
#  {'idx': 481, 'name': '358_cause_recodeclassVec_005'},
#  {'idx': 482, 'name': '358_cause_recodeclassVec_019'},
#  {'idx': 483, 'name': '113_cause_recodeclassVec_111'},
#  {'idx': 484, 'name': '113_cause_recodeclassVec_063'},
#  {'idx': 485, 'name': '113_cause_recodeclassVec_027'},
#  {'idx': 486, 'name': '113_cause_recodeclassVec_070'},
#  {'idx': 487, 'name': '113_cause_recodeclassVec_086'},
#  {'idx': 488, 'name': '113_cause_recodeclassVec_059'},
#  {'idx': 489, 'name': '113_cause_recodeclassVec_068'},
#  {'idx': 490, 'name': '113_cause_recodeclassVec_052'},
#  {'idx': 491, 'name': '113_cause_recodeclassVec_046'},
#  {'idx': 492, 'name': '113_cause_recodeclassVec_043'},
#  {'idx': 493, 'name': '113_cause_recodeclassVec_062'},
#  {'idx': 494, 'name': '113_cause_recodeclassVec_067'},
#  {'idx': 495, 'name': '113_cause_recodeclassVec_023'},
#  {'idx': 496, 'name': '113_cause_recodeclassVec_078'},
#  {'idx': 497, 'name': '113_cause_recodeclassVec_100'},
#  {'idx': 498, 'name': '113_cause_recodeclassVec_029'},
#  {'idx': 499, 'name': '113_cause_recodeclassVec_025'},
#  {'idx': 500, 'name': '113_cause_recodeclassVec_056'},
#  {'idx': 501, 'name': '113_cause_recodeclassVec_122'},
#  {'idx': 502, 'name': '113_cause_recodeclassVec_114'},
#  {'idx': 503, 'name': '113_cause_recodeclassVec_110'},
#  {'idx': 504, 'name': '113_cause_recodeclassVec_010'},
#  {'idx': 505, 'name': '113_cause_recodeclassVec_089'},
#  {'idx': 506, 'name': '113_cause_recodeclassVec_069'},
#  {'idx': 507, 'name': '113_cause_recodeclassVec_033'},
#  {'idx': 508, 'name': '113_cause_recodeclassVec_118'},
#  {'idx': 509, 'name': '113_cause_recodeclassVec_051'},
#  {'idx': 510, 'name': '113_cause_recodeclassVec_040'},
#  {'idx': 511, 'name': '113_cause_recodeclassVec_024'},
#  {'idx': 512, 'name': '113_cause_recodeclassVec_039'},
#  {'idx': 513, 'name': '113_cause_recodeclassVec_126'},
#  {'idx': 514, 'name': '113_cause_recodeclassVec_125'},
#  {'idx': 515, 'name': '113_cause_recodeclassVec_094'},
#  {'idx': 516, 'name': '113_cause_recodeclassVec_088'},
#  {'idx': 517, 'name': '113_cause_recodeclassVec_095'},
#  {'idx': 518, 'name': '113_cause_recodeclassVec_123'},
#  {'idx': 519, 'name': '113_cause_recodeclassVec_035'},
#  {'idx': 520, 'name': '113_cause_recodeclassVec_044'},
#  {'idx': 521, 'name': '113_cause_recodeclassVec_036'},
#  {'idx': 522, 'name': '113_cause_recodeclassVec_032'},
#  {'idx': 523, 'name': '113_cause_recodeclassVec_021'},
#  {'idx': 524, 'name': '113_cause_recodeclassVec_034'},
#  {'idx': 525, 'name': '113_cause_recodeclassVec_108'},
#  {'idx': 526, 'name': '113_cause_recodeclassVec_128'},
#  {'idx': 527, 'name': '113_cause_recodeclassVec_041'},
#  {'idx': 528, 'name': '113_cause_recodeclassVec_022'},
#  {'idx': 529, 'name': '113_cause_recodeclassVec_073'},
#  {'idx': 530, 'name': '113_cause_recodeclassVec_109'},
#  {'idx': 531, 'name': '113_cause_recodeclassVec_084'},
#  {'idx': 532, 'name': '113_cause_recodeclassVec_016'},
#  {'idx': 533, 'name': '113_cause_recodeclassVec_003'},
#  {'idx': 534, 'name': '113_cause_recodeclassVec_028'},
#  {'idx': 535, 'name': '113_cause_recodeclassVec_074'},
#  {'idx': 536, 'name': '113_cause_recodeclassVec_020'},
#  {'idx': 537, 'name': '113_cause_recodeclassVec_031'},
#  {'idx': 538, 'name': '113_cause_recodeclassVec_015'},
#  {'idx': 539, 'name': '113_cause_recodeclassVec_071'},
#  {'idx': 540, 'name': '113_cause_recodeclassVec_018'},
#  {'idx': 541, 'name': '113_cause_recodeclassVec_129'},
#  {'idx': 542, 'name': '113_cause_recodeclassVec_045'},
#  {'idx': 543, 'name': '113_cause_recodeclassVec_075'},
#  {'idx': 544, 'name': '113_cause_recodeclassVec_133'},
#  {'idx': 545, 'name': '113_cause_recodeclassVec_030'},
#  {'idx': 546, 'name': '113_cause_recodeclassVec_060'},
#  {'idx': 547, 'name': '113_cause_recodeclassVec_057'},
#  {'idx': 548, 'name': '113_cause_recodeclassVec_026'},
#  {'idx': 549, 'name': '113_cause_recodeclassVec_085'},
#  {'idx': 550, 'name': '113_cause_recodeclassVec_120'},
#  {'idx': 551, 'name': '113_cause_recodeclassVec_096'},
#  {'idx': 552, 'name': '113_cause_recodeclassVec_055'},
#  {'idx': 553, 'name': '113_cause_recodeclassVec_090'},
#  {'idx': 554, 'name': '113_cause_recodeclassVec_048'},
#  {'idx': 555, 'name': '113_cause_recodeclassVec_121'},
#  {'idx': 556, 'name': '113_cause_recodeclassVec_135'},
#  {'idx': 557, 'name': '113_cause_recodeclassVec_077'},
#  {'idx': 558, 'name': '113_cause_recodeclassVec_092'},
#  {'idx': 559, 'name': '113_cause_recodeclassVec_099'},
#  {'idx': 560, 'name': '113_cause_recodeclassVec_116'},
#  {'idx': 561, 'name': '113_cause_recodeclassVec_065'},
#  {'idx': 562, 'name': '113_cause_recodeclassVec_038'},
#  {'idx': 563, 'name': '113_cause_recodeclassVec_115'},
#  {'idx': 564, 'name': '113_cause_recodeclassVec_107'},
#  {'idx': 565, 'name': '113_cause_recodeclassVec_066'},
#  {'idx': 566, 'name': '113_cause_recodeclassVec_083'},
#  {'idx': 567, 'name': '113_cause_recodeclassVec_102'},
#  {'idx': 568, 'name': '113_cause_recodeclassVec_087'},
#  {'idx': 569, 'name': '113_cause_recodeclassVec_050'},
#  {'idx': 570, 'name': '113_cause_recodeclassVec_103'},
#  {'idx': 571, 'name': '113_cause_recodeclassVec_119'},
#  {'idx': 572, 'name': '113_cause_recodeclassVec_130'},
#  {'idx': 573, 'name': '113_cause_recodeclassVec_005'},
#  {'idx': 574, 'name': '113_cause_recodeclassVec_091'},
#  {'idx': 575, 'name': '113_cause_recodeclassVec_098'},
#  {'idx': 576, 'name': '113_cause_recodeclassVec_132'},
#  {'idx': 577, 'name': '113_cause_recodeclassVec_080'},
#  {'idx': 578, 'name': '113_cause_recodeclassVec_049'},
#  {'idx': 579, 'name': '113_cause_recodeclassVec_006'},
#  {'idx': 580, 'name': '113_cause_recodeclassVec_104'},
#  {'idx': 581, 'name': '113_cause_recodeclassVec_009'},
#  {'idx': 582, 'name': '113_cause_recodeclassVec_042'},
#  {'idx': 583, 'name': '113_cause_recodeclassVec_081'},
#  {'idx': 584, 'name': '113_cause_recodeclassVec_011'},
#  {'idx': 585, 'name': '113_cause_recodeclassVec_001'},
#  {'idx': 586, 'name': '113_cause_recodeclassVec_106'},
#  {'idx': 587, 'name': '113_cause_recodeclassVec_101'},
#  {'idx': 588, 'name': '113_cause_recodeclassVec_007'},
#  {'idx': 589, 'name': '113_cause_recodeclassVec_134'},
#  {'idx': 590, 'name': '113_cause_recodeclassVec_017'},
#  {'idx': 591, 'name': '113_cause_recodeclassVec_002'},
#  {'idx': 592, 'name': '113_cause_recodeclassVec_013'},
#  {'idx': 593, 'name': '113_cause_recodeclassVec_008'},
#  {'idx': 594, 'name': '130_infant_cause_recodeclassVec_000'},
#  {'idx': 595, 'name': '130_infant_cause_recodeclassVec_089'},
#  {'idx': 596, 'name': '130_infant_cause_recodeclassVec_135'},
#  {'idx': 597, 'name': '130_infant_cause_recodeclassVec_117'},
#  {'idx': 598, 'name': '130_infant_cause_recodeclassVec_123'},
#  {'idx': 599, 'name': '130_infant_cause_recodeclassVec_136'},
#  {'idx': 600, 'name': '130_infant_cause_recodeclassVec_090'},
#  {'idx': 601, 'name': '130_infant_cause_recodeclassVec_076'},
#  {'idx': 602, 'name': '130_infant_cause_recodeclassVec_146'},
#  {'idx': 603, 'name': '130_infant_cause_recodeclassVec_106'},
#  {'idx': 604, 'name': '130_infant_cause_recodeclassVec_096'},
#  {'idx': 605, 'name': '130_infant_cause_recodeclassVec_128'},
#  {'idx': 606, 'name': '130_infant_cause_recodeclassVec_132'},
#  {'idx': 607, 'name': '130_infant_cause_recodeclassVec_130'},
#  {'idx': 608, 'name': '130_infant_cause_recodeclassVec_080'},
#  {'idx': 609, 'name': '130_infant_cause_recodeclassVec_110'},
#  {'idx': 610, 'name': '130_infant_cause_recodeclassVec_127'},
#  {'idx': 611, 'name': '130_infant_cause_recodeclassVec_082'},
#  {'idx': 612, 'name': '130_infant_cause_recodeclassVec_075'},
#  {'idx': 613, 'name': '130_infant_cause_recodeclassVec_115'},
#  {'idx': 614, 'name': '130_infant_cause_recodeclassVec_125'},
#  {'idx': 615, 'name': '130_infant_cause_recodeclassVec_122'},
#  {'idx': 616, 'name': '130_infant_cause_recodeclassVec_119'},
#  {'idx': 617, 'name': '130_infant_cause_recodeclassVec_103'},
#  {'idx': 618, 'name': '130_infant_cause_recodeclassVec_062'},
#  {'idx': 619, 'name': '130_infant_cause_recodeclassVec_131'},
#  {'idx': 620, 'name': '130_infant_cause_recodeclassVec_044'},
#  {'idx': 621, 'name': '130_infant_cause_recodeclassVec_095'},
#  {'idx': 622, 'name': '130_infant_cause_recodeclassVec_009'},
#  {'idx': 623, 'name': '130_infant_cause_recodeclassVec_124'},
#  {'idx': 624, 'name': '130_infant_cause_recodeclassVec_078'},
#  {'idx': 625, 'name': '130_infant_cause_recodeclassVec_116'},
#  {'idx': 626, 'name': '130_infant_cause_recodeclassVec_003'},
#  {'idx': 627, 'name': '130_infant_cause_recodeclassVec_156'},
#  {'idx': 628, 'name': '130_infant_cause_recodeclassVec_077'},
#  {'idx': 629, 'name': '130_infant_cause_recodeclassVec_057'},
#  {'idx': 630, 'name': '130_infant_cause_recodeclassVec_108'},
#  {'idx': 631, 'name': '130_infant_cause_recodeclassVec_133'},
#  {'idx': 632, 'name': '130_infant_cause_recodeclassVec_147'},
#  {'idx': 633, 'name': '130_infant_cause_recodeclassVec_052'},
#  {'idx': 634, 'name': '130_infant_cause_recodeclassVec_101'},
#  {'idx': 635, 'name': '130_infant_cause_recodeclassVec_102'},
#  {'idx': 636, 'name': '130_infant_cause_recodeclassVec_094'},
#  {'idx': 637, 'name': '130_infant_cause_recodeclassVec_038'},
#  {'idx': 638, 'name': '130_infant_cause_recodeclassVec_066'},
#  {'idx': 639, 'name': '130_infant_cause_recodeclassVec_051'},
#  {'idx': 640, 'name': '130_infant_cause_recodeclassVec_084'},
#  {'idx': 641, 'name': '130_infant_cause_recodeclassVec_064'},
#  {'idx': 642, 'name': '130_infant_cause_recodeclassVec_100'},
#  {'idx': 643, 'name': '130_infant_cause_recodeclassVec_068'},
#  {'idx': 644, 'name': '130_infant_cause_recodeclassVec_049'},
#  {'idx': 645, 'name': '130_infant_cause_recodeclassVec_158'},
#  {'idx': 646, 'name': '130_infant_cause_recodeclassVec_018'},
#  {'idx': 647, 'name': '130_infant_cause_recodeclassVec_113'},
#  {'idx': 648, 'name': '130_infant_cause_recodeclassVec_087'},
#  {'idx': 649, 'name': '130_infant_cause_recodeclassVec_047'},
#  {'idx': 650, 'name': '130_infant_cause_recodeclassVec_141'},
#  {'idx': 651, 'name': '130_infant_cause_recodeclassVec_073'},
#  {'idx': 652, 'name': '130_infant_cause_recodeclassVec_120'},
#  {'idx': 653, 'name': '130_infant_cause_recodeclassVec_129'},
#  {'idx': 654, 'name': '130_infant_cause_recodeclassVec_072'},
#  {'idx': 655, 'name': '130_infant_cause_recodeclassVec_126'},
#  {'idx': 656, 'name': '130_infant_cause_recodeclassVec_155'},
#  {'idx': 657, 'name': '130_infant_cause_recodeclassVec_098'},
#  {'idx': 658, 'name': '130_infant_cause_recodeclassVec_104'},
#  {'idx': 659, 'name': '130_infant_cause_recodeclassVec_031'},
#  {'idx': 660, 'name': '130_infant_cause_recodeclassVec_040'},
#  {'idx': 661, 'name': '130_infant_cause_recodeclassVec_028'},
#  {'idx': 662, 'name': '130_infant_cause_recodeclassVec_148'},
#  {'idx': 663, 'name': '130_infant_cause_recodeclassVec_065'},
#  {'idx': 664, 'name': '130_infant_cause_recodeclassVec_099'},
#  {'idx': 665, 'name': '130_infant_cause_recodeclassVec_037'},
#  {'idx': 666, 'name': '130_infant_cause_recodeclassVec_085'},
#  {'idx': 667, 'name': '130_infant_cause_recodeclassVec_081'},
#  {'idx': 668, 'name': '130_infant_cause_recodeclassVec_151'},
#  {'idx': 669, 'name': '130_infant_cause_recodeclassVec_027'},
#  {'idx': 670, 'name': '130_infant_cause_recodeclassVec_145'},
#  {'idx': 671, 'name': '130_infant_cause_recodeclassVec_043'},
#  {'idx': 672, 'name': '130_infant_cause_recodeclassVec_058'},
#  {'idx': 673, 'name': '130_infant_cause_recodeclassVec_022'},
#  {'idx': 674, 'name': '130_infant_cause_recodeclassVec_153'},
#  {'idx': 675, 'name': '130_infant_cause_recodeclassVec_026'},
#  {'idx': 676, 'name': '130_infant_cause_recodeclassVec_069'},
#  {'idx': 677, 'name': '130_infant_cause_recodeclassVec_056'},
#  {'idx': 678, 'name': '130_infant_cause_recodeclassVec_149'},
#  {'idx': 679, 'name': '130_infant_cause_recodeclassVec_059'},
#  {'idx': 680, 'name': '130_infant_cause_recodeclassVec_121'},
#  {'idx': 681, 'name': '130_infant_cause_recodeclassVec_137'},
#  {'idx': 682, 'name': '130_infant_cause_recodeclassVec_032'},
#  {'idx': 683, 'name': '130_infant_cause_recodeclassVec_030'},
#  {'idx': 684, 'name': '130_infant_cause_recodeclassVec_157'},
#  {'idx': 685, 'name': '130_infant_cause_recodeclassVec_050'},
#  {'idx': 686, 'name': '130_infant_cause_recodeclassVec_092'},
#  {'idx': 687, 'name': '130_infant_cause_recodeclassVec_007'},
#  {'idx': 688, 'name': '130_infant_cause_recodeclassVec_048'},
#  {'idx': 689, 'name': '130_infant_cause_recodeclassVec_054'},
#  {'idx': 690, 'name': '130_infant_cause_recodeclassVec_112'},
#  {'idx': 691, 'name': '130_infant_cause_recodeclassVec_143'},
#  {'idx': 692, 'name': '130_infant_cause_recodeclassVec_150'},
#  {'idx': 693, 'name': '130_infant_cause_recodeclassVec_114'},
#  {'idx': 694, 'name': '130_infant_cause_recodeclassVec_061'},
#  {'idx': 695, 'name': '130_infant_cause_recodeclassVec_154'},
#  {'idx': 696, 'name': '130_infant_cause_recodeclassVec_002'},
#  {'idx': 697, 'name': '130_infant_cause_recodeclassVec_035'},
#  {'idx': 698, 'name': '130_infant_cause_recodeclassVec_008'},
#  {'idx': 699, 'name': '130_infant_cause_recodeclassVec_041'},
#  {'idx': 700, 'name': '130_infant_cause_recodeclassVec_042'},
#  {'idx': 701, 'name': '130_infant_cause_recodeclassVec_019'},
#  {'idx': 702, 'name': '130_infant_cause_recodeclassVec_036'},
#  {'idx': 703, 'name': '130_infant_cause_recodeclassVec_034'},
#  {'idx': 704, 'name': '130_infant_cause_recodeclassVec_060'},
#  {'idx': 705, 'name': '130_infant_cause_recodeclassVec_144'},
#  {'idx': 706, 'name': '130_infant_cause_recodeclassVec_045'},
#  {'idx': 707, 'name': '130_infant_cause_recodeclassVec_107'},
#  {'idx': 708, 'name': '130_infant_cause_recodeclassVec_016'},
#  {'idx': 709, 'name': '130_infant_cause_recodeclassVec_083'},
#  {'idx': 710, 'name': '130_infant_cause_recodeclassVec_142'},
#  {'idx': 711, 'name': '130_infant_cause_recodeclassVec_010'},
#  {'idx': 712, 'name': '130_infant_cause_recodeclassVec_021'},
#  {'idx': 713, 'name': '130_infant_cause_recodeclassVec_111'},
#  {'idx': 714, 'name': '130_infant_cause_recodeclassVec_004'},
#  {'idx': 715, 'name': '130_infant_cause_recodeclassVec_025'},
#  {'idx': 716, 'name': '39_cause_recodeclassVec_37'},
#  {'idx': 717, 'name': '39_cause_recodeclassVec_21'},
#  {'idx': 718, 'name': '39_cause_recodeclassVec_22'},
#  {'idx': 719, 'name': '39_cause_recodeclassVec_08'},
#  {'idx': 720, 'name': '39_cause_recodeclassVec_15'},
#  {'idx': 721, 'name': '39_cause_recodeclassVec_28'},
#  {'idx': 722, 'name': '39_cause_recodeclassVec_24'},
#  {'idx': 723, 'name': '39_cause_recodeclassVec_39'},
#  {'idx': 724, 'name': '39_cause_recodeclassVec_17'},
#  {'idx': 725, 'name': '39_cause_recodeclassVec_16'},
#  {'idx': 726, 'name': '39_cause_recodeclassVec_27'},
#  {'idx': 727, 'name': '39_cause_recodeclassVec_06'},
#  {'idx': 728, 'name': '39_cause_recodeclassVec_31'},
#  {'idx': 729, 'name': '39_cause_recodeclassVec_09'},
#  {'idx': 730, 'name': '39_cause_recodeclassVec_20'},
#  {'idx': 731, 'name': '39_cause_recodeclassVec_40'},
#  {'idx': 732, 'name': '39_cause_recodeclassVec_07'},
#  {'idx': 733, 'name': '39_cause_recodeclassVec_38'},
#  {'idx': 734, 'name': '39_cause_recodeclassVec_30'},
#  {'idx': 735, 'name': '39_cause_recodeclassVec_36'},
#  {'idx': 736, 'name': '39_cause_recodeclassVec_12'},
#  {'idx': 737, 'name': '39_cause_recodeclassVec_23'},
#  {'idx': 738, 'name': '39_cause_recodeclassVec_11'},
#  {'idx': 739, 'name': '39_cause_recodeclassVec_10'},
#  {'idx': 740, 'name': '39_cause_recodeclassVec_14'},
#  {'idx': 741, 'name': '39_cause_recodeclassVec_13'},
#  {'idx': 742, 'name': '39_cause_recodeclassVec_26'},
#  {'idx': 743, 'name': '39_cause_recodeclassVec_41'},
#  {'idx': 744, 'name': '39_cause_recodeclassVec_33'},
#  {'idx': 745, 'name': '39_cause_recodeclassVec_05'},
#  {'idx': 746, 'name': '39_cause_recodeclassVec_34'},
#  {'idx': 747, 'name': '39_cause_recodeclassVec_03'},
#  {'idx': 748, 'name': '39_cause_recodeclassVec_25'},
#  {'idx': 749, 'name': '39_cause_recodeclassVec_42'},
#  {'idx': 750, 'name': '39_cause_recodeclassVec_29'},
#  {'idx': 751, 'name': '39_cause_recodeclassVec_35'},
#  {'idx': 752, 'name': '39_cause_recodeclassVec_32'},
#  {'idx': 753, 'name': '39_cause_recodeclassVec_01'},
#  {'idx': 754, 'name': 'raceclassVec_01'},
#  {'idx': 755, 'name': 'raceclassVec_02'},
#  {'idx': 756, 'name': 'raceclassVec_03'},
#  {'idx': 757, 'name': 'raceclassVec_04'},
#  {'idx': 758, 'name': 'raceclassVec_07'},
#  {'idx': 759, 'name': 'raceclassVec_05'},
#  {'idx': 760, 'name': 'raceclassVec_18'},
#  {'idx': 761, 'name': 'raceclassVec_68'},
#  {'idx': 762, 'name': 'raceclassVec_28'},
#  {'idx': 763, 'name': 'raceclassVec_48'},
#  {'idx': 764, 'name': 'raceclassVec_78'},
#  {'idx': 765, 'name': 'raceclassVec_38'},
#  {'idx': 766, 'name': 'raceclassVec_06'},
#  {'idx': 767, 'name': 'race_recode_3classVec_1'},
#  {'idx': 768, 'name': 'race_recode_3classVec_3'},
#  {'idx': 769, 'name': 'race_recode_5classVec_1'},
#  {'idx': 770, 'name': 'race_recode_5classVec_2'},
#  {'idx': 771, 'name': 'race_recode_5classVec_4'},
#  {'idx': 772, 'name': 'hispanic_originrace_recodeclassVec_6'},
#  {'idx': 773, 'name': 'hispanic_originrace_recodeclassVec_7'},
#  {'idx': 774, 'name': 'hispanic_originrace_recodeclassVec_1'},
#  {'idx': 775, 'name': 'hispanic_originrace_recodeclassVec_8'},
#  {'idx': 776, 'name': 'hispanic_originrace_recodeclassVec_2'},
#  {'idx': 777, 'name': 'hispanic_originrace_recodeclassVec_5'},
#  {'idx': 778, 'name': 'hispanic_originrace_recodeclassVec_4'},
#  {'idx': 779, 'name': 'hispanic_originrace_recodeclassVec_3'},
#  {'idx': 780, 'name': 'number_of_entity_axis_conditions'},
#  {'idx': 781, 'name': 'number_of_record_axis_conditions'}]

# %%
features_name_ind[0]['name']
# Out:
# 'resident_statusclassVec_1'

# %%
feature_names = ['intercept']
for i in features_name_ind:
    feature_names.append(i['name'])
# Out:
# ['intercept', 'resident_statusclassVec_1', 'resident_statusclassVec_2', 'resident_statusclassVec_3', 'education_2003_revisionclassVec_3', 'education_2003_revisionclassVec_1', 'education_2003_revisionclassVec_4', 'education_2003_revisionclassVec_2', 'education_2003_revisionclassVec_6', 'education_2003_revisionclassVec_5', 'education_2003_revisionclassVec_7', 'education_2003_revisionclassVec_9', 'month_of_deathclassVec_01', 'month_of_deathclassVec_12', 'month_of_deathclassVec_03', 'month_of_deathclassVec_11', 'month_of_deathclassVec_10', 'month_of_deathclassVec_02', 'month_of_deathclassVec_04', 'month_of_deathclassVec_05', 'month_of_deathclassVec_07', 'month_of_deathclassVec_08', 'month_of_deathclassVec_09', 'sexclassVec_M', 'age_recode_52classVec_43', 'age_recode_52classVec_42', 'age_recode_52classVec_41', 'age_recode_52classVec_44', 'age_recode_52classVec_40', 'age_recode_52classVec_39', 'age_recode_52classVec_38', 'age_recode_52classVec_37', 'age_recode_52classVec_36', 'age_recode_52classVec_45', 'age_recode_52classVec_35', 'age_recode_52classVec_34', 'age_recode_52classVec_33', 'age_recode_52classVec_32', 'age_recode_52classVec_46', 'age_recode_52classVec_31', 'age_recode_52classVec_30', 'age_recode_52classVec_29', 'age_recode_52classVec_02', 'age_recode_52classVec_01', 'age_recode_52classVec_28', 'age_recode_52classVec_27', 'age_recode_52classVec_12', 'age_recode_52classVec_23', 'age_recode_52classVec_47', 'age_recode_52classVec_13', 'age_recode_52classVec_09', 'age_recode_52classVec_14', 'age_recode_52classVec_24', 'age_recode_52classVec_03', 'age_recode_52classVec_10', 'age_recode_52classVec_15', 'age_recode_52classVec_25', 'age_recode_52classVec_04', 'age_recode_52classVec_11', 'age_recode_52classVec_26', 'age_recode_52classVec_16', 'age_recode_52classVec_17', 'age_recode_52classVec_05', 'age_recode_52classVec_18', 'age_recode_52classVec_06', 'age_recode_52classVec_07', 'age_recode_52classVec_19', 'age_recode_52classVec_08', 'age_recode_52classVec_20', 'age_recode_52classVec_52', 'age_recode_52classVec_22', 'age_recode_52classVec_21', 'age_recode_52classVec_48', 'age_recode_52classVec_49', 'age_recode_52classVec_50', 'Place_of_death_and_decedents_statusclassVec_1', 'Place_of_death_and_decedents_statusclassVec_4', 'Place_of_death_and_decedents_statusclassVec_6', 'Place_of_death_and_decedents_statusclassVec_2', 'Place_of_death_and_decedents_statusclassVec_5', 'Place_of_death_and_decedents_statusclassVec_7', 'marital_statusclassVec_M', 'marital_statusclassVec_W', 'marital_statusclassVec_D', 'marital_statusclassVec_S', 'day_of_week_of_deathclassVec_7', 'day_of_week_of_deathclassVec_6', 'day_of_week_of_deathclassVec_2', 'day_of_week_of_deathclassVec_5', 'day_of_week_of_deathclassVec_4', 'day_of_week_of_deathclassVec_3', 'day_of_week_of_deathclassVec_1', 'current_data_yearclassVec_2015', 'current_data_yearclassVec_2014', 'current_data_yearclassVec_2013', 'current_data_yearclassVec_2012', 'current_data_yearclassVec_2011', 'current_data_yearclassVec_2010', 'current_data_yearclassVec_2008', 'current_data_yearclassVec_2009', 'current_data_yearclassVec_2007', 'current_data_yearclassVec_2006', 'injury_at_workclassVec_U', 'injury_at_workclassVec_N', 'manner_of_deathclassVec_7', 'manner_of_deathclassVec_8', 'manner_of_deathclassVec_1', 'manner_of_deathclassVec_2', 'manner_of_deathclassVec_3', 'manner_of_deathclassVec_5', 'autopsyclassVec_N', 'autopsyclassVec_Y', 'autopsyclassVec_U', 'autopsyclassVec_n', 'activity_codeclassVec_10', 'activity_codeclassVec_9', 'activity_codeclassVec_4', 'activity_codeclassVec_2', 'activity_codeclassVec_0', 'activity_codeclassVec_8', 'activity_codeclassVec_1', 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_10', 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_0', 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_9', 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_8', 'place_of_injury_for_causes_w00_y34_except_y06_and_y07_classVec_1', 'place_of_ ...

# %%
pvalues = lrModel.summary.pValues
len(pvalues)
# Out:
# 783

# %%
intercept = lrModel.intercept
coefficients = list(lrModel.coefficients)
coefficients.insert(0, intercept)
coefficients
# Out:
# [-0.39246637221373254,
#  0.046720960993353766,
#  -0.08716687962191344,
#  0.03302791352535616,
#  -0.024990141739336287,
#  -0.3087845238912354,
#  0.10017297347643474,
#  -0.08762353146512557,
#  0.14495346964456915,
#  0.0530049552829441,
#  0.07923801108325626,
#  -0.016477756960348776,
#  -0.014634109147210873,
#  0.015224379794424153,
#  -0.007481315556300118,
#  0.009461788372710809,
#  0.004255151607741193,
#  -0.010459919805591958,
#  -0.006848515052451526,
#  -0.0023860448916742942,
#  0.001552725496770674,
#  0.005163985511986896,
#  0.004121763633382317,
#  0.0934284189784431,
#  -0.15998548755595826,
#  -0.09888053472835225,
#  -0.022831890536473467,
#  -0.17558613753604166,
#  0.05544871445333076,
#  0.11033598769549097,
#  0.13899043235341627,
#  0.14327322928571076,
#  0.11656769567801095,
#  -0.1205949740916935,
#  0.06599416006097132,
#  0.03067575914437255,
#  0.008055309530822395,
#  -0.0035216083605450663,
#  -0.035202416774891755,
#  -0.013085861501510051,
#  -0.02257809945421992,
#  -0.02010953168809902,
#  0.017723805605672847,
#  0.010855998086218174,
#  -0.004795274521065963,
#  -0.004429685360301353,
#  -0.0010898482016084103,
#  -0.003394953320298248,
#  -0.0034020960361183347,
#  -0.0017187829454332938,
#  0.0010612828638400956,
#  -0.0013076823099075377,
#  -0.0022605670193234753,
#  0.001456729720915826,
#  0.0002058181908390831,
#  -0.0009969149064527885,
#  -0.0017987434434761666,
#  0.001149079817021398,
#  7.78869923371607e-05,
#  -0.0014822566746001834,
#  -0.0009480139945145371,
#  -0.0005990174987641591,
#  0.0004827109958111311,
#  -0.0005402825113684642,
#  0.00020936586547579835,
#  0.00032278477387646384,
#  -0.0005850707056869115,
#  0.00024520634724423986,
#  -0.0002998363696648018,
#  -0.00012580423598384922,
#  -0.00041288008943950335,
#  -0.00039779006601594154,
#  -0.00016585371258577583,
#  -4.102625815285323e-06,
#  -2.2777250151124974e-06,
#  -0.05886321737645478,
#  0.03844988488015418,
#  -0.06236317582418164,
#  -0.05936100874531502,
#  0.12812534746846477,
#  0.025987558498752374,
#  -0.08104125483534402,
#  -0.26493685990882654,
#  0.3004445155529251,
#  0.04041279530415177,
#  -0.0035337130830084495,
#  0.0017076735327009088,
#  0.00041241986353124306,
#  0.004140740488351771,
#  0.0015850534151772829,
#  0.0006132735193699006,
#  -0.005383485601952222,
#  0.13264724272780615,
#  0.09198034557687043,
#  0.05012845496482076,
#  0.017158973900036685,
#  0.01582593674999943,
#  -0.007119086192203524,
#  -0.06427606918559897,
#  -0.0204847383903386,
#  -0.06633575704417104,
#  -0.06695073244052895,
#  -0.01838358390656114,
#  0.025252360940252086,
#  0.0719995412893118,
#  -0.10847020672744997,
#  0.010941908266257355,
#  0.04694072877551992,
#  -0.026423264798197427,
#  0.0036875914308184387,
#  -0.022511578657458182,
#  0.07716345974155699,
#  -0.054656552064297946,
#  2.64629965089263e-06,
#  -0.012759533981042735,
#  0.01167463354820485,
#  0.0004661525160655082,
#  -0.00023374722142435172,
#  -5.36092199906025e-05,
#  0.0004751068941922853,
#  0.0004052237769315268,
#  -0.03135736444209004,
#  0.04494664019238625,
#  -0.01489469912298933,
#  0.001546819885584239,
#  0.004568300466877706,
#  -0.007134428292638367,
#  0.00448026886594632,
#  5.003028480323425e-05,
#  -0.0006177221300696052,
#  -0.001443773774812727,
#  -0.028875526778359084,
#  0.03413293653855078,
#  0.03347709714933727,
#  -0.02840854280350119,
#  -0.03201239566452882,
#  -0.026922777886932564,
#  -0.011429036105818644,
#  -0.013211950652063134,
#  0.03296739032514967,
#  -0.028494410839535064,
#  -0.023519621472920613,
#  -0.005984663082744564,
#  -0.01921621770851806,
#  0.002576835959221716,
#  -0.008670665167171755,
#  0.006275291873532637,
#  -0.0014263676153923243,
#  0.004956597088206783,
#  0.03341481464269833,
#  -0.008910341522451575,
#  0.0015176503113962037,
#  -0.004260751656750445,
#  -0.001130627841458063,
#  -0.003591200568122701,
#  -0.004249593474331837,
#  0.005236181794880939,
#  -0.009647924431217852,
#  -0.0037397999473562315,
#  0.02245679431891879,
#  0.0343281214313596,
#  -0.003220735024606642,
#  0.009227007456787858,
#  -0.018887408376700388,
#  -0.008357614682759373,
#  0.008916157768836109,
#  -0.003072957545970484,
#  0.004159328906243844,
#  -0.006798089334101758,
#  -0.003462454723132456,
#  -0.0021596003509820345,
#  0.0005750348972317277,
#  0.00836555172509859,
#  -0.0017690008646612466,
#  -0.0004285446801638453,
#  -0.0028785077526483267,
#  -0.0008183059650990172,
#  0.0029756042168150344,
#  -0.0021342410144626414,
#  -0.02223560421540028,
#  -0.004935417773443655,
#  -0.006614901860169349,
#  -0.0060624933463985405,
#  -0.0006699408000183889,
#  0.006527281912519365,
#  0.008297143989474256,
#  0.0037967242829402984,
#  -0.0025942984862945867,
#  0.005366114993056093,
#  0.005831331505109557,
#  -0.011154556685216312,
#  0.0024810084915905654,
#  0.0019298372219529976,
#  0.0014028042212885074,
#  -0.0020467931468946877,
#  0.0173412290874832,
#  0.0008321947583330489,
#  -0.0009874962143737861,
#  0.01761575379281284,
#  -0.002357721877513738,
#  -0.0012748209809043496,
#  0.00042345379584684303,
#  -0.00026688086365334913,
#  -0.002797199799643969,
#  0.007683101782472444,
#  -0.00397519218259955,
#  0.00981962439328008,
#  -0.005666442649939876,
#  -0.002097007109076389,
#  0.001947350938528972,
#  0.011670335043546186,
#  5.922731411419936e-05,
#  -0.0011524343685992654,
#  -0.0011659744606413271,
#  -0.0019853882332823655,
#  0.00016816862561397586,
#  0.0021450284013857235,
#  -0.0034343983012296167,
#  -0.00042487990186336315,
#  0.00292434197085091,
#  0.013477072908677959,
#  -0.0007710620523307893,
#  -0.0012683591147124508,
#  0.0027646806724261463,
#  0.0029045904356229915,
#  -0.002027097316764937,
#  -0.00040965433945909177,
#  0.0002682817745705919,
#  -0.002090226480429147,
#  0.006596709079807465,
#  -0.0012696139887254088,
#  0.0025688948390466767,
#  -0.000991940217637851,
#  0.00047548457516851143,
#  0.0014249156457132788,
#  0.0012678188951965627,
#  -0.0008655693919353941,
#  0.005537905612113293,
#  0.00218169443111762,
#  0.001106574651667336,
#  0.009370812173813147,
#  0.0005457226178440331,
#  0.004403871581244879,
#  -0.0008440883436845766,
#  -0.0008099154467864977,
#  -0.0014616962886850916,
#  0.00014235910176267215,
#  0.00041956480812130315,
#  0.0028901463396676444,
#  -0.0010128596652041022,
#  -0.0018889425773407082,
#  -0.0011896144504862179,
#  -0.0010380907858751076,
#  -0.0010256025445605544,
#  -0.002508019669746552,
#  -2.6501326957492912e-05,
#  -0.0004061946106260653,
#  0.003370744994468892,
#  0.005630731560347644,
#  0.0026497630957950883,
#  -0.0008804589102159496,
#  0.00025759253308190697,
#  0.0010819646235191902,
#  -0.0006207002587472902,
#  -0.0002517615366094448,
#  -0.0005776098969972835,
#  4.6679591860667726e-05,
#  -3.814332343436956e-05,
#  -8.11786781248813e-05,
#  -0.003371674152710357,
#  -0.000367231774234016,
#  0.0006292529907745704,
#  -0.002313732381817506,
#  0.00014736423829937812,
#  0.0034530841378331337,
#  -0.00012423652919832308,
#  -0.0009242751320839444,
#  -0.0023014530091691426,
#  -0.0003233708101997002,
#  -0.0007047567836738869,
#  0.0008206755992226914,
#  0.0002005766524409586,
#  -0.00014026364969452635,
#  -0.00020258015193814647,
#  -0.0008658980691558415,
#  -0.0002203002380666672,
#  0.00033349649322522235,
#  -0.0010144933646291188,
#  -0.00025236778862574915,
#  -0.0005521087319392082,
#  0.0008023953217203158,
#  -0.00027436098124292076,
#  0.0008750355900354522,
#  -1.04923769666829e-05,
#  -0.00015363082377613366,
#  0.0002664794787831242,
#  -0.0005303851347217221,
#  0.002229815331930279,
#  -2.9983915590341626e-05,
#  0.002327697990407552,
#  0.0005742485841693461,
#  0.0002113879567172679,
#  -0.0004044211280908832,
#  -0.001609566930818768,
#  -0.0013341549570638558,
#  0.00038935689981264333,
#  -8.034166172185802e-05,
#  -0.00018441841286484626,
#  -0.0006152906193417214,
#  0.0009806258999059754,
#  0.0003708988776487116,
#  3.566733934303541e-05,
#  0.0009779899962745922,
#  -0.00036385102419942393,
#  -0.0001079653381793209,
#  -0.0003055318170797121,
#  -5.2444754058998864e-05,
#  0.0003400179200974821,
#  0.0012821525897942557,
#  -0.00011907882932387294,
#  0.0005975958391335539,
#  -0.0004944044868635005,
#  -2.2595070236513748e-05,
#  0.0004878204668892725,
#  0.0015656299256232684,
#  1.4347213754084535e-05,
#  0.0005749402702000577,
#  8.861619655745867e-05,
#  -8.697173105918348e-05,
#  0.0007045960857054503,
#  1.318647040997596e-05,
#  0.0005046809427347195,
#  -8.708696859617175e-05,
#  -0.0005174575696374219,
#  -9.164870163960225e-05,
#  0.0001880857554564444,
#  0.00018454855714569634,
#  0.000841960289963483,
#  -9.528970675915917e-05,
#  -0.0002926275105296317,
#  -0.000686133367515224,
#  -6.553676367545877e-05,
#  -3.7351995068127806e-05,
#  0.00013119453788708899,
#  -0.0003092439888062945,
#  1.65366208898254e-05,
#  4.9658540573398915e-05,
#  -6.00674998823895e-07,
#  0.0006773861894044415,
#  4.571352278860051e-05,
#  0.00022558002820824815,
#  3.7595730139046786e-05,
#  0.00018615516975203352,
#  0.00014935170185013545,
#  2.0840608140911676e-05,
#  0.000392828343466582,
#  7.212733467575385e-05,
#  2.795397766254462e-05,
#  1.9248812623736445e-05,
#  5.7157790297920145e-05,
#  2.8325440269450804e-05,
#  0.0003566205882944583,
#  -0.000308504463100226,
#  0.0003153696706973528,
#  -7.946444788010653e-05,
#  -0.00036186439081595554,
#  -0.0001960780657334397,
#  0.0001408351623260556,
#  2.8461551467814096e-05,
#  -3.372039474748477e-05,
#  8.980970229894452e-05,
#  -0.0005985627200968971,
#  -7.11550006130601e-05,
#  -0.0002526781439086443,
#  0.0005458987923433656,
#  -3.005430437268821e-05,
#  3.064983972498783e-05,
#  -4.682336423644191e-05,
#  -0.00017949764901799647,
#  0.00018119967868115026,
#  -4.110522613607275e-06,
#  -8.691836930745126e-05,
#  -2.987391955078294e-05,
#  -0.00015423708795986204,
#  6.378827098044478e-05,
#  1.305634966349223e-05,
#  -0.0001990924302703282,
#  -2.078928684586751e-05,
#  6.056588245085205e-05,
#  -2.7317512096985574e-05,
#  3.676107206459888e-05,
#  -0.00014929183751291895,
#  -1.554725304134231e-05,
#  -9.101244755883895e-05,
#  -7.296957012410454e-05,
#  -6.0499024678631105e-05,
#  -2.1301259472972464e-05,
#  6.866958074392843e-05,
#  -3.462081513307347e-05,
#  -8.878749958323553e-05,
#  -0.0002918132890242332,
#  -0.00011424844507293124,
#  -0.00011447740964658816,
#  3.474074839546216e-05,
#  -0.0002188168694270298,
#  -1.585098606798411e-05,
#  7.912789563937705e-05,
#  0.00012055233098501904,
#  6.202076734262918e-05,
#  9.035608541348355e-05,
#  -6.501402734290494e-06,
#  -2.0481416228558516e-05,
#  2.1275822465928207e-05,
#  1.674772159555869e-05,
#  -5.538182531321935e-05,
#  2.38522186379706e-05,
#  5.6164042816310135e-05,
#  -2.2438982568732663e-05,
#  -3.991133971688159e-05,
#  -4.304413431847555e-06,
#  -2.2061304931351976e-05,
#  -5.3564135648329636e-05,
#  -5.115129138660108e-05,
#  -6.673472158557778e-05,
#  -6.757307945074688e-05,
#  -2.264441145614113e-05,
#  4.149126756819087e-05,
#  -1.1146619581059421e-05,
#  3.446070378767395e-05,
#  -3.5397009833686097e-06,
#  0.00014296028284576203,
#  -8.24400476632875e-05,
#  7.952300817936347e-06,
#  1.5030262628500881e-05,
#  -3.402021456829153e-05,
#  -3.993590232530596e-05,
#  9.23636724033836e-05,
#  4.6463093584785163e-05,
#  6.277980808618068e-06,
#  4.1120313003852796e-05,
#  -4.718802238019763e-05,
#  1.5245588374966475e-05,
#  -3.7420293944588414e-05,
#  5.417111258831226e-06,
#  3.5697827077796195e-06,
#  2.501546085195214e-05,
#  2.1892272074475887e-05,
#  -3.001477564477803e-05,
#  -3.025838959922818e-06,
#  -1.9817239928910405e-05,
#  -9.700841922912677e-06,
#  7.913623186970102e-06,
#  -1.247186639949599e-06,
#  7.729438871933368e-06,
#  2.3056677886098082e-05,
#  -1.6798226101393858e-05,
#  1.1215370621431503e-05,
#  4.53502737047306e-06,
#  -3.598572210931503e-06,
#  -1.0431049956391993e-05,
#  1.6548914193917946e-05,
#  3.775661002591652e-06,
#  9.155833656965782e-06,
#  -2.029829644773612e-05,
#  3.0407145210093504e-06,
#  9.366141956118568e-07,
#  -9.67119948147634e-06,
#  -5.517489591261948e-06,
#  -3.99926245073949e-06,
#  -3.007624422994224e-07,
#  1.2211784262156924e-06,
#  -1.7165952990862968e-06,
#  -7.936816259332866e-06,
#  2.839302708274067e-06,
#  6.194759969104314e-07,
#  3.4989006842812827e-06,
#  3.7260317410280857e-06,
#  2.8456651410255696e-06,
#  -1.0252654563309993e-07,
#  -2.7279857067773874e-06,
#  -2.96135223697755e-06,
#  4.414217618106615e-07,
#  -1.614886510072676e-06,
#  -1.4196003596512394e-06,
#  0.00234009888435662,
#  -0.028875526778359077,
#  0.0341329365385507,
#  -0.018681939960141617,
#  0.032861806529995694,
#  -0.028408542803501084,
#  -0.011565958467390258,
#  -0.026922777886932574,
#  -0.011429036105818647,
#  0.0005265168941964082,
#  0.03296739032514962,
#  -0.032469603022134544,
#  -0.0022215020013597654,
#  -0.023281394002722916,
#  -0.01921621770851805,
#  0.002576835959221715,
#  -0.001426367615392323,
#  0.004956597088206791,
#  0.03358543544472092,
#  -0.02857804603374921,
#  0.0026254651232829,
#  -0.00891034152245159,
#  -0.004110246640286079,
#  -0.005815033510901192,
#  -0.0011306278414580594,
#  0.0031234269093313783,
#  -0.009647924431217848,
#  -0.005487149648077798,
#  0.008061032996146513,
#  -0.0037397999473562328,
#  0.02416353505525073,
#  0.02245679431891877,
#  0.03432812143135961,
#  -0.00836804573271578,
#  0.008978178536178707,
#  -0.017905467589672843,
#  0.00415932890624384,
#  -0.0012368121345448756,
#  -0.0022465187202894907,
#  0.0005750348972317269,
#  0.008365551725098569,
#  -0.0028785077526483306,
#  0.030031340488660876,
#  -0.02223560421540034,
#  -0.005921658184072484,
#  -0.006614901860169341,
#  0.0037967242829402966,
#  -0.00018145580604630402,
#  0.005831331505109579,
#  0.01957385269401905,
#  -0.0009408166225131428,
#  0.001929837221953016,
#  0.0014028042212885074,
#  0.0074242045845973464,
#  -0.0020467931468946916,
#  0.017341229087483208,
#  -0.00235772187751374,
#  0.00014194112927875678,
#  -0.0038103475613010013,
#  -0.0017018913525968973,
#  0.000686872531885774,
#  0.0034907152921076637,
#  0.002924341970850907,
#  -0.0007710620523307904,
#  -0.0012683591147124428,
#  0.0029045904356229937,
#  -0.00040965433945909106,
#  -0.0020902264804291445,
#  -0.0009919402176378532,
#  0.00016225569021037094,
#  0.0013465229227759149,
#  -0.0009167206833219933,
#  0.0001423591017626731,
#  -0.0006092396062825999,
#  -0.0010256025445605525,
#  -3.814332343436889e-05,
#  -0.0008782067128278208,
#  0.0012373339909694696,
#  0.0008023953217203151,
#  -1.0492376966683162e-05,
#  0.0002005628185882254,
#  -0.0010707352055333904,
#  -0.00011907882932387294,
#  -0.0005045825288336657,
#  -4.110421472245001e-05,
#  -0.0005174575696374208,
#  0.00018454855714569626,
#  -9.52897067591587e-05,
#  -0.0006861333675152241,
#  0.00018055601298480882,
#  2.0840608140911714e-05,
#  1.9248812623736523e-05,
#  -3.664027291385132e-05,
#  -2.9873919550783015e-05,
#  -0.00015423708795986202,
#  6.0565882450852144e-05,
#  -1.554725304134232e-05,
#  6.866958074392818e-05,
#  -2.048141622855851e-05,
#  2.1275822465928186e-05,
#  -2.2644411456141113e-05,
#  3.435563677264122e-05,
#  1.3415376118428216e-05,
#  -2.260637795326608e-05,
#  -2.932069766056723e-05,
#  -3.0014775644777987e-05,
#  -1.9817239928910378e-05,
#  2.3056677886098096e-05,
#  -8.734585285864479e-06,
#  1.654891419391794e-05,
#  -3.0076244229942267e-07,
#  -0.02489454966039415,
#  0.010627091756529908,
#  -0.003371674152710356,
#  0.0024524164757412886,
#  -0.0001934258657810311,
#  -0.0014920574715333072,
#  0.002857328334016044,
#  0.002858877436212994,
#  -0.0013704389278872489,
#  0.0004515094606745316,
#  0.0008419602899634806,
#  0.0003983509910035782,
#  0.000639229291588303,
#  0.00015984602642680972,
#  0.001076645483355452,
#  0.0010422241226367523,
#  0.0003684604040437415,
#  0.0018315266976821278,
#  0.0018354198785114288,
#  0.0004023205029711012,
#  0.00041784723595740975,
#  0.00025644308605756095,
#  0.00031867653813596867,
#  0.00043672081220890477,
#  5.857085407103805e-05,
#  0.0002976733037478377,
#  -0.00014446930655442726,
#  0.0001996290648254722,
#  -3.2298000618272064e-05,
#  6.674470296759861e-05,
#  0.0003670945405951026,
#  0.00017686327433005583,
#  0.0002283361183560398,
#  -0.0002765554432638888,
#  0.000578542565348091,
#  -0.00021386031674659395,
#  0.0001470386155121045,
#  0.00014163431873502488,
#  -0.00034891633890748303,
#  -5.99853724125117e-05,
#  0.00029378068358723537,
#  1.908208159667409e-05,
#  0.00017428425919978176,
#  -0.00016322044759811393,
#  -2.141936397260935e-06,
#  3.211296806866306e-05,
#  0.00025023007430796705,
#  2.9441093956915393e-05,
#  0.00018663959277086335,
#  0.00014014294823306016,
#  -4.144687920867877e-05,
#  -0.00012455309235838086,
#  -0.00011011907456714711,
#  9.551815400228806e-05,
#  0.00025558318748247224,
#  1.6431528294897665e-05,
#  -0.0002054434385871827,
#  0.00013652185016247936,
#  0.00016144527416560084,
#  7.147721131017497e-05,
#  0.00029653973371505883,
#  -1.2343106813061819e-05,
#  -3.2537804759535545e-05,
#  9.617373965110977e-05,
#  1.144498215506366e-05,
#  6.859689394474278e-05,
#  -2.820574230369554e-05,
#  6.0352361610490914e-05,
#  -0.0001155263626516294,
#  -1.2297437817401165e-05,
#  -5.528674848202243e-05,
#  9.649484589507878e-06,
#  8.6070743786324e-05,
#  4.682951382511262e-05,
#  -6.99427037251494e-05,
#  8.454635305294697e-06,
#  -8.731405572128602e-05,
#  -2.0857652458008052e-05,
#  -6.061784877627873e-05,
#  -2.2689442420150454e-05,
#  -7.146386551392642e-05,
#  -2.7851934700166423e-05,
#  -6.00957017868327e-05,
#  -1.6796501357549307e-05,
#  -5.0668581249000174e-05,
#  -6.945866958953666e-05,
#  5.160075329648694e-05,
#  -3.4371827752472915e-05,
#  -7.598851676167117e-06,
#  -1.3342141823794328e-05,
#  -1.2049993946299751e-05,
#  -2.0581646483598786e-05,
#  1.4196247257488046e-05,
#  -2.127158281035308e-05,
#  -6.004213052061844e-06,
#  -1.4501189003340782e-05,
#  -9.42004990571386e-06,
#  -2.5659722963494453e-05,
#  -4.0629970807415766e-05,
#  2.450371328179218e-05,
#  -3.322484599949843e-05,
#  -1.7898625263315103e-05,
#  -9.30433747220408e-06,
#  -4.167708897413239e-06,
#  -1.4916083395340573e-05,
#  6.785139311980652e-06,
#  8.583193093374417e-06,
#  -1.098336113933626e-05,
#  -1.8766327067966682e-06,
#  -1.178590079355628e-05,
#  -1.3134342088966068e-05,
#  -2.5488481671537708e-06,
#  -2.1034252200653525e-06,
#  -2.2695185667349123e-06,
#  7.729742200014597e-07,
#  6.0199546539451555e-06,
#  -6.384258080987365e-06,
#  5.164888672098333e-06,
#  1.4432262574157484e-06,
#  -7.593030483450942e-06,
#  -2.5959673141224687e-06,
#  4.4326934946143465e-06,
#  -0.016856510334928868,
#  -0.025087741309041477,
#  -0.04318998930691848,
#  0.034132936538550714,
#  0.021076935468988384,
#  0.03777890116681238,
#  -0.0186819399601416,
#  0.0169980512214729,
#  -0.026922777886932554,
#  -0.011429036105818653,
#  -0.024306996547283657,
#  -0.002221502001359752,
#  -0.020160385391920357,
#  0.002576835959221713,
#  0.0036882379734943867,
#  0.04662032937416961,
#  -0.001426367615392323,
#  -0.028578046033749208,
#  0.043306299967538264,
#  0.005997139275993237,
#  0.001258226083358993,
#  -0.005815033510901197,
#  -0.0011306278414580646,
#  0.0014525837211879194,
#  -0.005487149648077798,
#  -0.003739799947356225,
#  0.005199528504228857,
#  -0.026045951776701347,
#  0.03003134048866089,
#  -0.006614901860169331,
#  -0.00018145580604630218,
#  0.019573852694019046,
#  -0.0023577218775137423,
#  0.0036215801456127893,
#  0.0013465229227759157,
#  -0.003371674152710356,
#  -0.0010933415834866568,
#  5.293355099569672e-06,
#  0.07844577600044694,
#  -0.10714849183733943,
#  -0.025666702538609937,
#  -0.01606195421404858,
#  -0.009942461788812985,
#  0.02175987362167486,
#  0.03420744623875124,
#  0.00916491511883247,
#  -0.0006722211730422615,
#  0.009838805458404046,
#  0.0054925127196296065,
#  -0.0019448851591197342,
#  0.0024653859609074322,
#  0.07844577600044712,
#  -0.10714849183733935,
#  0.078445776000447,
#  -0.10714849183733928,
#  0.05436941837551055,
#  0.17764752321481259,
#  -0.11261976203896225,
#  -0.14221516279316268,
#  0.02527784753573743,
#  0.00617779560338945,
#  0.00047436201833322023,
#  0.010656205239580439,
#  0.03111578235120781,
#  0.034814931206199815,
#  -0.039453476479660174]

# %%
df_values = [('feature_names', feature_names), ('coefficients', coefficients),('p_values', pvalues)]
inference_df = pd.DataFrame.from_items(df_values)

# %%
inference_df.head(20)
# Out:
#                         feature_names  coefficients      p_values
# 0                           intercept     -0.392466  0.000000e+00
# 1           resident_statusclassVec_1      0.046721  0.000000e+00
# 2           resident_statusclassVec_2     -0.087167  0.000000e+00
# 3           resident_statusclassVec_3      0.033028  0.000000e+00
# 4   education_2003_revisionclassVec_3     -0.024990  0.000000e+00
# 5   education_2003_revisionclassVec_1     -0.308785  0.000000e+00
# 6   education_2003_revisionclassVec_4      0.100173  0.000000e+00
# 7   education_2003_revisionclassVec_2     -0.087624  0.000000e+00
# 8   education_2003_revisionclassVec_6      0.144953  0.000000e+00
# 9   education_2003_revisionclassVec_5      0.053005  0.000000e+00
# 10  education_2003_revisionclassVec_7      0.079238  0.000000e+00
# 11  education_2003_revisionclassVec_9     -0.016478  0.000000e+00
# 12          month_of_deathclassVec_01     -0.014634  0.000000e+00
# 13          month_of_deathclassVec_12      0.015224  5.264175e-08
# 14          month_of_deathclassVec_03     -0.007481  1.010547e-11
# 15          month_of_deathclassVec_11      0.009462  2.220563e-03
# 16          month_of_deathclassVec_10      0.004255  5.817569e-14
# 17          month_of_deathclassVec_02     -0.010460  8.848419e-07
# 18          month_of_deathclassVec_04     -0.006849  8.707270e-02
# 19          month_of_deathclassVec_05     -0.002386  2.676255e-01

# %%
inference_df.to_csv('inference_df.csv')

# %%
predictions = lrModel.transform(testData)

# %%
predictions.select("label", "prediction", "probability", 'resident_status').show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-f6dc5d1873db> in <module>()
# ----> 1 predictions.select("label", "prediction", "probability", 'resident_status').show()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pyspark/sql/dataframe.py in show(self, n, truncate)
#     334         """
#     335         if isinstance(truncate, bool) and truncate:
# --> 336             print(self._jdf.showString(n, 20))
#     337         else:
#     338             print(self._jdf.showString(n, int(truncate)))
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1129             proto.END_COMMAND_PART
#    1130
# -> 1131         answer = self.gateway_client.send_command(command)
#    1132         return_value = get_return_value(
#    1133             answer, self.gateway_client, self.target_id, self.name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#     881         connection = self._get_connection()
#     882         try:
# --> 883             response = connection.send_command(command)
#     884             if binary:
#     885                 return response, self._create_connection_guard(connection)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/py4j/java_gateway.py in send_command(self, command)
#    1026
#    1027         try:
# -> 1028             answer = smart_decode(self.stream.readline()[:-1])
#    1029             logger.debug("Answer received: {0}".format(answer))
#    1030             if answer.startswith(proto.RETURN_MESSAGE):
#
# ~/anaconda3/envs/python3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Out:
# <bound method HasInputCols.getInputCols of VectorAssembler_441aac334f4bd0abed85>

# %%
evaluator = BinaryClassificationEvaluator(rawPredictionCol="rawPrediction")
evaluator.evaluate(predictions)
# Out:
# 0.6818197121020716

# %%
evaluator.getMetricName()
# Out:
# 'areaUnderROC'

# %%
tp = selected.where(selected["label"] == 1).where(selected["prediction"] == 1).count()
tn = selected.where(selected["label"] == 0).where(selected["prediction"] == 0).count()
fp = selected.where(selected["label"] == 0).where(selected["prediction"] == 1).count()
fn = selected.where(selected["label"] == 1).where(selected["prediction"] == 0).count()

# %%
accuracy = (tp + tn) * 100 / (tp + tn + fp + fn)
accuracy
# Out:
# 63.83987205636665

# %%
precision = tp / (tp + fp)
precision
# Out:
# 0.6175657058859233

# %%
recall = tp / (tp + fn)
recall
# Out:
# 0.4969072444187992

# %%
f1_score = 2 * precision * recall / (precision + recall)
f1_score
# Out:
# 0.5507049284155684

# %%
lrModel.save('logistic_model.model')

# %%
lrmodel = LogisticRegression.load(path='')
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-53-d42995e8be4a> in <module>()
# ----> 1 lrmodel = LogisticRegression.load('logistic_model')
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pyspark/ml/util.py in load(cls, path)
#     255     def load(cls, path):
#     256         """Reads an ML instance from the input path, a shortcut of `read().load(path)`."""
# --> 257         return cls.read().load(path)
#     258
#     259
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pyspark/ml/util.py in load(self, path)
#     195         if not isinstance(path, basestring):
#     196             raise TypeError("path should be a basestring, got type %s" % type(path))
# --> 197         java_obj = self._jread.load(path)
#     198         if not hasattr(self._clazz, "_from_java"):
#     199             raise NotImplementedError("This Java ML type cannot be loaded into Python currently: %r"
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1131         answer = self.gateway_client.send_command(command)
#    1132         return_value = get_return_value(
# -> 1133             answer, self.gateway_client, self.target_id, self.name)
#    1134
#    1135         for temp_arg in temp_args:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     317                 raise Py4JJavaError(
#     318                     "An error occurred while calling {0}{1}{2}.\n".
# --> 319                     format(target_id, ".", name), value)
#     320             else:
#     321                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o1145.load.
# : java.lang.NoSuchMethodException: org.apache.spark.ml.classification.LogisticRegressionModel.<init>(java.lang.String)
# 	at java.lang.Class.getConstructor0(Class.java:3082)
# 	at java.lang.Class.getConstructor(Class.java:1825)
# 	at org.apache.spark.ml.util.DefaultParamsReader.load(ReadWrite.scala:328)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:280)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:214)
# 	at java.lang.Thread.run(Thread.java:745)

# %%
rf = RandomForestClassifier(labelCol="label", featuresCol="features")

# %%
rfModel = rf.fit(trainingData)

# %%
predictions = rfModel.transform(testData)

# %%
predictions.printSchema()
# Out:
# root
#  |-- label: double (nullable = true)
#  |-- features: vector (nullable = true)
#  |-- resident_status: string (nullable = true)
#  |-- education_2003_revision: string (nullable = true)
#  |-- month_of_death: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- age_recode_52: string (nullable = true)
#  |-- Place_of_death_and_decedents_status: string (nullable = false)
#  |-- marital_status: string (nullable = true)
#  |-- day_of_week_of_death: string (nullable = true)
#  |-- current_data_year: string (nullable = true)
#  |-- injury_at_work: string (nullable = true)
#  |-- manner_of_death: string (nullable = false)
#  |-- method_of_disposition: string (nullable = true)
#  |-- autopsy: string (nullable = true)
#  |-- activity_code: string (nullable = false)
#  |-- place_of_injury_for_causes_w00_y34_except_y06_and_y07_: string (nullable = false)
#  |-- 358_cause_recode: string (nullable = true)
#  |-- 113_cause_recode: string (nullable = true)
#  |-- 130_infant_cause_recode: string (nullable = false)
#  |-- 39_cause_recode: string (nullable = true)
#  |-- number_of_entity_axis_conditions: double (nullable = true)
#  |-- number_of_record_axis_conditions: double (nullable = true)
#  |-- race: string (nullable = true)
#  |-- race_recode_3: string (nullable = true)
#  |-- race_recode_5: string (nullable = true)
#  |-- hispanic_originrace_recode: string (nullable = true)
#  |-- rawPrediction: vector (nullable = true)
#  |-- probability: vector (nullable = true)
#  |-- prediction: double (nullable = true)

# %%
selected = predictions.select("label", "prediction", "probability")

# %%
evaluator = BinaryClassificationEvaluator()
evaluator.evaluate(predictions)
# Out:
# 0.6585139971498309

# %%
tp = selected.where(selected["label"] == 1).where(selected["prediction"] == 1).count()

# %%
tn = selected.where(selected["label"] == 0).where(selected["prediction"] == 0).count()
fp = selected.where(selected["label"] == 0).where(selected["prediction"] == 1).count()
fn = selected.where(selected["label"] == 1).where(selected["prediction"] == 0).count()

# %%
accuracy = (tp + tn) * 100 / (tp + tn + fp + fn)
accuracy
# Out:
# 59.852210662949055

# %%
precision = tp / (tp + fp)
precision
# Out:
# 0.6760139560824394

# %%
recall = tp / (tp + fn)
recall
# Out:
# 0.19241678982932794

# %%
f1_score = 2 * precision * recall / (precision + recall)
f1_score
# Out:
# 0.29956662847683896

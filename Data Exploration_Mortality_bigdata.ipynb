# %%
import os
import pandas as pd
import numpy as np
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession, SQLContext
from pyspark.sql.types import *
import pyspark.sql.functions as fn
from pyspark.sql.functions import col, udf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Reading 11 CSV files into pyspark dataframe

# %%
year1 = (spark.read.csv(path='/FileStore/tables/2005_data.csv',header=True,inferSchema=True, ignoreLeadingWhiteSpace=True, ignoreTrailingWhiteSpace=True).cache())
year2 = (spark.read.csv(path='/FileStore/tables/2006_data.csv',header=True,inferSchema=True, ignoreLeadingWhiteSpace=True, ignoreTrailingWhiteSpace=True).cache())
year3 = (spark.read.csv(path='/FileStore/tables/2007_data.csv',header=True,inferSchema=True, ignoreLeadingWhiteSpace=True, ignoreTrailingWhiteSpace=True).cache())
year4 = (spark.read.csv(path='/FileStore/tables/2008_data.csv',header=True,inferSchema=True, ignoreLeadingWhiteSpace=True, ignoreTrailingWhiteSpace=True).cache())
year5 = (spark.read.csv(path='/FileStore/tables/2009_data.csv',header=True,inferSchema=True, ignoreLeadingWhiteSpace=True, ignoreTrailingWhiteSpace=True).cache())
year6 = (spark.read.csv(path='/FileStore/tables/2010_data.csv',header=True,inferSchema=True, ignoreLeadingWhiteSpace=True, ignoreTrailingWhiteSpace=True).cache())
year7 = (spark.read.csv(path='/FileStore/tables/2011_data.csv',header=True,inferSchema=True, ignoreLeadingWhiteSpace=True, ignoreTrailingWhiteSpace=True).cache())
year8 = (spark.read.csv(path='/FileStore/tables/2012_data.csv',header=True,inferSchema=True, ignoreLeadingWhiteSpace=True, ignoreTrailingWhiteSpace=True).cache())
year9 = (spark.read.csv(path='/FileStore/tables/2013_data.csv',header=True,inferSchema=True, ignoreLeadingWhiteSpace=True, ignoreTrailingWhiteSpace=True).cache())
year10 = (spark.read.csv(path='/FileStore/tables/2014_data.csv',header=True,inferSchema=True, ignoreLeadingWhiteSpace=True, ignoreTrailingWhiteSpace=True).cache())
year11 = (spark.read.csv(path='/FileStore/tables/2015_data.csv',header=True,inferSchema=True, ignoreLeadingWhiteSpace=True, ignoreTrailingWhiteSpace=True).cache())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Merging all the dataframes and generating the merged dataset.

# %%
df = year1.union(year2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_2 = df.union(year3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_3 = df_2.union(year4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_4 = df_3.union(year5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_5 = df_4.union(year6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_6 = df_5.union(year7)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_7 = df_6.union(year8)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_8 = df_7.union(year9)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_9 = df_8.union(year10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_10 = df_9.union(year11)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_10.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>27720673
# </div>

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>4883231
# </div>

# %%
df_10.schema.names
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">15</span><span class="ansired">]: </span>
# [&apos;resident_status&apos;,
#  &apos;education_1989_revision&apos;,
#  &apos;education_2003_revision&apos;,
#  &apos;education_reporting_flag&apos;,
#  &apos;month_of_death&apos;,
#  &apos;sex&apos;,
#  &apos;detail_age_type&apos;,
#  &apos;detail_age&apos;,
#  &apos;age_substitution_flag&apos;,
#  &apos;age_recode_52&apos;,
#  &apos;age_recode_27&apos;,
#  &apos;age_recode_12&apos;,
#  &apos;infant_age_recode_22&apos;,
#  &apos;place_of_death_and_decedents_status&apos;,
#  &apos;marital_status&apos;,
# ...

# %% [markdown]
# ##### Dropping the redundant columns

# %%
df_11 = df_10.drop('detail_age_type','detail_age', 'age_substitution_flag','age_recode_27', 'age_recode_12', 'infant_age_recode_22', 'icd_code_10th_revision')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_11.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">17</span><span class="ansired">]: </span>
# [(&apos;resident_status&apos;, &apos;int&apos;),
#  (&apos;education_1989_revision&apos;, &apos;int&apos;),
#  (&apos;education_2003_revision&apos;, &apos;int&apos;),
#  (&apos;education_reporting_flag&apos;, &apos;int&apos;),
#  (&apos;month_of_death&apos;, &apos;int&apos;),
#  (&apos;sex&apos;, &apos;string&apos;),
#  (&apos;age_recode_52&apos;, &apos;int&apos;),
#  (&apos;place_of_death_and_decedents_status&apos;, &apos;int&apos;),
#  (&apos;marital_status&apos;, &apos;string&apos;),
# ...

# %% [markdown]
# ##### Cleaning the dataset and handling null values.

# %%
from pyspark.sql.functions import col, countDistinct
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_11.groupBy('record_condition_5').count().orderBy('count', ascending=False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+--------+
# record_condition_5|   count|
# +------------------+--------+
#               null|23373017|
#               I500|  234948|
#               J449|  204386|
#               J969|  184552|
#               I469|  174498|
#                I10|  141868|
#               I251|  127004|
#                I48|  123785|
#                N19|  115467|
#               J189|  104085|
#               N179|   92797|
#               N189|   83823|
#                I64|   78033|
#               R628|   75391|
#               R092|   75273|
#               J960|   65429|
#               R688|   56043|
# ...

# %%
df_12 = df_11.drop('record_condition_20' , 'entity_condition_20', 'entity_condition_19', 'entity_condition_18', 'entity_condition_17', 'record_condition_19', 'record_condition_18', 'record_condition_16', 'record_condition_17','record_condition_15','record_condition_14','record_condition_13','record_condition_12','record_condition_11','record_condition_10','record_condition_9','record_condition_8','record_condition_7' , 'record_condition_6', 'record_condition_5', 'entity_condition_16', 'entity_condition_15','entity_condition_14', 'entity_condition_13', 'entity_condition_12', 'entity_condition_11', 'entity_condition_10', 'entity_condition_9','entity_condition_8', 'entity_condition_7', 'entity_condition_6', 'entity_condition_5')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_12.groupBy('current_data_year').count().orderBy('count', ascending=False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------+
# current_data_year|  count|
# +-----------------+-------+
#              2015|2718198|
#              2014|2631171|
#              2013|2601452|
#              2012|2547864|
#              2011|2519842|
#              2008|2476811|
#              2010|2472542|
#              2005|2452506|
#              2009|2441219|
#              2006|2430725|
#              2007|2428343|
# +-----------------+-------+
#
# </div>

# %%
df_12 = df_12.fillna({'place_of_injury_for_causes_w00_y34_except_y06_and_y07_' : 10})
df_12.groupBy('place_of_injury_for_causes_w00_y34_except_y06_and_y07_').count().orderBy('count', ascending=False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------------------------------------------+--------+
# place_of_injury_for_causes_w00_y34_except_y06_and_y07_|   count|
# +------------------------------------------------------+--------+
#                                                     10|25774726|
#                                                      0|  929731|
#                                                      9|  593002|
#                                                      8|  158625|
#                                                      1|   81772|
#                                                      4|   81155|
# ...

# %%
df_12 = df_12.fillna({'130_infant_cause_recode' : 000})
df_12.groupBy('130_infant_cause_recode').count().orderBy('count', ascending=False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------------+--------+
# 130_infant_cause_recode|   count|
# +-----------------------+--------+
#                       0|27437006|
#                      89|   37483|
#                     135|   21918|
#                     117|   14657|
#                     123|   13609|
#                     136|   12614|
#                      90|   11278|
#                      76|    8810|
#                     146|    7741|
#                     106|    7237|
#                      96|    6699|
#                     128|    6267|
#                     132|    5886|
#                      80|    5638|
# ...

# %%
df_12 = df_12.fillna({'activity_code' : 10})
df_12.groupBy('activity_code').count().orderBy('count', ascending=False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+--------+
# activity_code|   count|
# +-------------+--------+
#            10|25678617|
#             9| 2034168|
#             2|    1858|
#             4|    1720|
#             0|    1662|
#             8|    1307|
#             1|    1198|
#             3|     143|
# +-------------+--------+
#
# </div>

# %%
from pyspark.sql.functions import *
df_12 = df_12.withColumn('method_of_disposition', regexp_replace('method_of_disposition', 'R' , 'O'))
df_12 = df_12.withColumn('method_of_disposition', regexp_replace('method_of_disposition', 'E' , 'O'))
df_12 = df_12.withColumn('method_of_disposition', regexp_replace('method_of_disposition', 'D' , 'O'))
df_12.groupBy('method_of_disposition').count().orderBy('count', ascending=False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------------+--------+
# method_of_disposition|   count|
# +---------------------+--------+
#                     B|10088982|
#                     U| 8390896|
#                     C| 8121832|
#                     O| 1118963|
# +---------------------+--------+
#
# </div>

# %%
df_12 = df_12.fillna({'manner_of_death' : 8})
df_12.groupBy('manner_of_death').count().orderBy('count', ascending=False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------+--------+
# manner_of_death|   count|
# +---------------+--------+
#               7|19914162|
#               8| 5656790|
#               1| 1350268|
#               2|  423361|
#               3|  200528|
#               5|  119756|
#               4|   55808|
# +---------------+--------+
#
# </div>

# %%
from pyspark.sql.functions import when 
df_12 = df_12.withColumn('Place_of_death_and_decedents_status', when(df_12['Place_of_death_and_decedents_status']== 9 , 7).otherwise(df['Place_of_death_and_decedents_status']))
df_12.groupBy('Place_of_death_and_decedents_status').count().orderBy('count', ascending=False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------------------------+-------+
# Place_of_death_and_decedents_status|  count|
# +-----------------------------------+-------+
#                                   1|9172308|
#                                   4|7504084|
#                                   6|5782818|
#                                   2|1904155|
#                                   7|1888985|
#                                   5|1287142|
#                                   3| 181181|
# +-----------------------------------+-------+
#
# </div>

# %%
display(df_12.select("sex","current_data_year").groupBy("current_data_year").agg(count("sex")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_data_year</th><th>count(sex)</th></tr></thead><tbody><tr><td>2007</td><td>2428343</td></tr><tr><td>2015</td><td>2718198</td></tr><tr><td>2006</td><td>2430725</td></tr><tr><td>2013</td><td>2601452</td></tr><tr><td>2014</td><td>2631171</td></tr><tr><td>2012</td><td>2547864</td></tr><tr><td>2009</td><td>2441219</td></tr><tr><td>2005</td><td>2452506</td></tr><tr><td>2010</td><td>2472542</td></tr><tr><td>2011</td><td>2519842</td></tr><tr><td>2008</td><td>2476811</td></tr></tbody></table></div>

# %% [markdown]
# ###### Visualizations using Temp Table in pyspark and forming pivot tables. Visualizations were done in databricks.

# %%
from pyspark.sql import Row

df_12.registerTempTable("largeTable")
display(sqlContext.sql("select * from largeTable"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select current_data_year, sex, count("sex") from largeTable group by current_data_year, sex order by current_data_year, sex
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select current_data_year, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (407, 429,435,446) group by current_data_year, 358_cause_recode order by current_data_year, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select current_data_year, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (407, 429,435,446) and current_data_year IN (2015,2014,2013,2012,2011) group by current_data_year, 358_cause_recode order by current_data_year, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select sex, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (407, 429,435,446) group by sex, 358_cause_recode order by sex, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sex</th><th>358_cause_recode</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>F</td><td>407</td><td>859</td></tr><tr><td>F</td><td>429</td><td>28050</td></tr><tr><td>F</td><td>435</td><td>20102</td></tr><tr><td>F</td><td>446</td><td>572</td></tr><tr><td>M</td><td>407</td><td>5667</td></tr><tr><td>M</td><td>429</td><td>184930</td></tr><tr><td>M</td><td>435</td><td>110726</td></tr><tr><td>M</td><td>446</td><td>2253</td></tr></tbody></table></div>

# %%
# %sql select race_recode_5, sex, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (429) group by race_recode_5, sex, 358_cause_recode order by race_recode_5, sex, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>race_recode_5</th><th>sex</th><th>358_cause_recode</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>1</td><td>F</td><td>429</td><td>26260</td></tr><tr><td>1</td><td>M</td><td>429</td><td>170515</td></tr><tr><td>2</td><td>F</td><td>429</td><td>1206</td></tr><tr><td>2</td><td>M</td><td>429</td><td>10622</td></tr><tr><td>3</td><td>F</td><td>429</td><td>264</td></tr><tr><td>3</td><td>M</td><td>429</td><td>1653</td></tr><tr><td>4</td><td>F</td><td>429</td><td>320</td></tr><tr><td>4</td><td>M</td><td>429</td><td>2140</td></tr></tbody></table></div>

# %%
# %sql select race_recode_5, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (435) group by race_recode_5, 358_cause_recode order by race_recode_5, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>race_recode_5</th><th>358_cause_recode</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>1</td><td>435</td><td>54347</td></tr><tr><td>2</td><td>435</td><td>72929</td></tr><tr><td>3</td><td>435</td><td>1244</td></tr><tr><td>4</td><td>435</td><td>2308</td></tr></tbody></table></div>

# %%
# %sql select race_recode_5, sex 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (435) group by race_recode_5, sex, 358_cause_recode order by race_recode_5, sex, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>race_recode_5</th><th>358_cause_recode</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>1</td><td>F</td><td>12217</td></tr><tr><td>1</td><td>M</td><td>42130</td></tr><tr><td>2</td><td>F</td><td>7184</td></tr><tr><td>2</td><td>M</td><td>65745</td></tr><tr><td>3</td><td>F</td><td>209</td></tr><tr><td>3</td><td>M</td><td>1035</td></tr><tr><td>4</td><td>F</td><td>492</td></tr><tr><td>4</td><td>M</td><td>1816</td></tr></tbody></table></div>

# %%
# %sql select sex, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (407, 429,435,446) group by sex, 358_cause_recode order by sex, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sex</th><th>358_cause_recode</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>F</td><td>407</td><td>859</td></tr><tr><td>F</td><td>429</td><td>28050</td></tr><tr><td>F</td><td>435</td><td>20102</td></tr><tr><td>F</td><td>446</td><td>572</td></tr><tr><td>M</td><td>407</td><td>5667</td></tr><tr><td>M</td><td>429</td><td>184930</td></tr><tr><td>M</td><td>435</td><td>110726</td></tr><tr><td>M</td><td>446</td><td>2253</td></tr></tbody></table></div>

# %%
# %sql select age_recode_52, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (407, 429,435,446) group by age_recode_52, 358_cause_recode order by count("358_cause_recode") desc, age_recode_52, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select current_data_year, age_recode_52, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (407, 429,435,446) and age_recode_52 IN(23,24,25,26,27,28,29) group by current_data_year, age_recode_52, 358_cause_recode order by  current_data_year, count("358_cause_recode") desc, age_recode_52, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select race_recode_5, 358_cause_recode , count("358_cause_recode") from largeTable where age_recode_52 IN (23, 24,25,26,27,28,29) and race_recode_5 = 2 group by race_recode_5, 358_cause_recode order by count("358_cause_recode") desc, race_recode_5, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select 358_cause_recode , count("358_cause_recode") from largeTable where age_recode_52 IN (23, 24,25,26,27,28,29) group by   358_cause_recode order by count("358_cause_recode") desc, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select current_data_year, age_recode_52, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (407, 429,435,446) and age_recode_52 IN(28,29) group by current_data_year, age_recode_52, 358_cause_recode order by  current_data_year, count("358_cause_recode") desc, age_recode_52, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select current_data_year, place_of_injury_for_causes_w00_y34_except_y06_and_y07_, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (435) group by current_data_year, place_of_injury_for_causes_w00_y34_except_y06_and_y07_, 358_cause_recode order by current_data_year, count("358_cause_recode") desc, place_of_injury_for_causes_w00_y34_except_y06_and_y07_, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select month_of_death, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (407, 429,435,446) group by month_of_death, 358_cause_recode order by count("358_cause_recode") desc, month_of_death, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select day_of_week_of_death, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (407, 429,435,446) group by day_of_week_of_death, 358_cause_recode order by count("358_cause_recode") desc, day_of_week_of_death, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select place_of_death_and_decedents_status, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (407, 429,435,446) group by place_of_death_and_decedents_status, 358_cause_recode order by count("358_cause_recode") desc, place_of_death_and_decedents_status, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select race_recode_5, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (407, 429,435,446) group by race_recode_5, 358_cause_recode order by count("358_cause_recode") desc, race_recode_5, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select resident_status, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (407, 429,435,446) group by resident_status, 358_cause_recode order by count("358_cause_recode") desc, resident_status, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select age_recode_52, 358_cause_recode , count("age_recode_52") from largeTable group by age_recode_52, 358_cause_recode order by count("age_recode_52") desc, age_recode_52, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select month_of_death, 358_cause_recode , count("358_cause_recode") from largeTable group by month_of_death, 358_cause_recode order by count("358_cause_recode") desc, month_of_death, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select month_of_death, 39_cause_recode , count("39_cause_recode") from largeTable group by month_of_death, 39_cause_recode order by count("39_cause_recode") desc, month_of_death, 39_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select day_of_week_of_death, 39_cause_recode , count("39_cause_recode") from largeTable group by day_of_week_of_death, 39_cause_recode order by count("39_cause_recode") desc, day_of_week_of_death, 39_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select race_recode_5, 358_cause_recode , count("358_cause_recode") from largeTable where age_recode_52 IN (23, 24,25,26,27,28,29) and 358_cause_recode in (435) group by   race_recode_5, 358_cause_recode order by count("358_cause_recode") desc, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>race_recode_5</th><th>358_cause_recode</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>2</td><td>435</td><td>12071</td></tr><tr><td>1</td><td>435</td><td>7230</td></tr><tr><td>4</td><td>435</td><td>284</td></tr><tr><td>3</td><td>435</td><td>190</td></tr></tbody></table></div>

# %%
# %sql select place_of_injury_for_causes_w00_y34_except_y06_and_y07_,358_cause_recode , count("358_cause_recode") from largeTable where age_recode_52 IN (23, 24,25,26,27,28,29) and 358_cause_recode in (407,429,435,446) group by place_of_injury_for_causes_w00_y34_except_y06_and_y07_, 358_cause_recode order by count("358_cause_recode") desc, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select race_recode_3, count("race_recode_3") from largeTable where 358_cause_recode IN (450,451) group by race_recode_3 order by count("358_cause_recode") desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>race_recode_3</th><th>count(race_recode_3)</th></tr></thead><tbody><tr><td>1</td><td>3517</td></tr><tr><td>3</td><td>1371</td></tr><tr><td>2</td><td>201</td></tr></tbody></table></div>

# %%
# %sql select current_data_year, count("current_data_year") from largeTable where 358_cause_recode IN (420,443) group by current_data_year order by count("current_data_year") asc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_data_year</th><th>count(current_data_year)</th></tr></thead><tbody><tr><td>2005</td><td>25594</td></tr><tr><td>2006</td><td>29862</td></tr><tr><td>2007</td><td>31256</td></tr><tr><td>2008</td><td>31461</td></tr><tr><td>2009</td><td>31974</td></tr><tr><td>2010</td><td>33038</td></tr><tr><td>2012</td><td>36066</td></tr><tr><td>2011</td><td>36068</td></tr><tr><td>2013</td><td>38585</td></tr><tr><td>2014</td><td>41667</td></tr><tr><td>2015</td><td>47314</td></tr></tbody></table></div>

# %%
# %sql select race_recode_5, 358_cause_recode , count("358_cause_recode") from largeTable where 358_cause_recode IN (342,433) group by race_recode_5, 358_cause_recode order by count("358_cause_recode") desc, race_recode_5, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>race_recode_5</th><th>358_cause_recode</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>1</td><td>433</td><td>793</td></tr><tr><td>2</td><td>433</td><td>236</td></tr><tr><td>1</td><td>342</td><td>26</td></tr><tr><td>4</td><td>433</td><td>25</td></tr><tr><td>2</td><td>342</td><td>18</td></tr><tr><td>3</td><td>433</td><td>12</td></tr><tr><td>4</td><td>342</td><td>3</td></tr><tr><td>3</td><td>342</td><td>1</td></tr></tbody></table></div>

# %%
# %sql select current_data_year, count("358_cause_recode") from largeTable where manner_of_death = 2  group by  current_data_year ,358_cause_recode order by count("358_cause_recode") desc,  current_data_year, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select current_data_year, 358_cause_recode, count("358_cause_recode") from largeTable where manner_of_death = 2 and 358_cause_recode IN (424,
425,
426,
427,
428,
429,
430,
431) group by  current_data_year ,358_cause_recode order by count("358_cause_recode") desc,  current_data_year, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select entity_condition_1, 358_cause_recode, count("358_cause_recode") from largeTable where manner_of_death = 2 and 358_cause_recode IN (424,
425,
426,
427,
428,
429,
430,
431) group by entity_condition_1 ,358_cause_recode order by count("358_cause_recode") desc,  entity_condition_1, 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select count("358_cause_recode") from largeTable where manner_of_death = 2 and 358_cause_recode IN (424,
425,
426,
427,
428,
429,
430,
431)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>420925</td></tr></tbody></table></div>

# %%
# %sql select count("358_cause_recode") from largeTable where 358_cause_recode IN (407,
429,
435,
446,
450,
451)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>358248</td></tr></tbody></table></div>

# %%
# %sql select count("358_cause_recode") from largeTable where 358_cause_recode IN (
429)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>212980</td></tr></tbody></table></div>

# %%
# %sql select count("358_cause_recode") from largeTable where 358_cause_recode IN (407,
429,
435,
446,
450,
451) and age_recode_52 in (27,28,29)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>30192</td></tr></tbody></table></div>

# %%
# %sql select count("358_cause_recode") from largeTable where 358_cause_recode IN (429) and age_recode_52 in (27,28,29)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>9106</td></tr></tbody></table></div>

# %%
# %sql select current_data_year, count("358_cause_recode") from largeTable where 358_cause_recode IN (435) group by current_data_year order by current_data_year
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_data_year</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>2005</td><td>12402</td></tr><tr><td>2006</td><td>12844</td></tr><tr><td>2007</td><td>12698</td></tr><tr><td>2008</td><td>12227</td></tr><tr><td>2009</td><td>11537</td></tr><tr><td>2010</td><td>11113</td></tr><tr><td>2011</td><td>11105</td></tr><tr><td>2012</td><td>11667</td></tr><tr><td>2013</td><td>11230</td></tr><tr><td>2014</td><td>10982</td></tr><tr><td>2015</td><td>13023</td></tr></tbody></table></div>

# %%
# %sql select race, count("race") from largeTable group by race order by count("race") desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>race</th><th>count(race)</th></tr></thead><tbody><tr><td>1</td><td>23703335</td></tr><tr><td>2</td><td>3258257</td></tr><tr><td>3</td><td>174392</td></tr><tr><td>4</td><td>125944</td></tr><tr><td>7</td><td>106432</td></tr><tr><td>68</td><td>94127</td></tr><tr><td>5</td><td>78973</td></tr><tr><td>18</td><td>55418</td></tr><tr><td>28</td><td>42810</td></tr><tr><td>48</td><td>39420</td></tr><tr><td>78</td><td>25672</td></tr><tr><td>6</td><td>7363</td></tr><tr><td>38</td><td>5688</td></tr><tr><td>58</td><td>2842</td></tr></tbody></table></div>

# %%
pt = sqlContext.sql("select  race,count(race) from largeTable group by race order by count(race) desc")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pt.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----------+
# race|count(race)|
# +----+-----------+
#    1|   23703335|
#    2|    3258257|
#    3|     174392|
#    4|     125944|
#    7|     106432|
#   68|      94127|
#    5|      78973|
#   18|      55418|
#   28|      42810|
#   48|      39420|
#   78|      25672|
#    6|       7363|
#   38|       5688|
#   58|       2842|
# +----+-----------+
#
# </div>

# %%
pt = pt.withColumnRenamed("count(race)","Total")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pt.registerTempTable("largeTable2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sumtotal = sqlContext.sql("select(sum(Total)) from largeTable2")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sumtotal.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+
# sum(Total)|
# +----------+
#   27720673|
# +----------+
#
# </div>

# %%
sumtotal = sumtotal.withColumnRenamed("sum(total)","sumtotal")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
abc = sqlContext.sql("select current_data_year, month_of_death, count(358_cause_recode) as total from largeTable where manner_of_death = 2 group by current_data_year, month_of_death order by  current_data_year, month_of_death")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
abc.registerTempTable('sf')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql select * from sf
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
ls = sqlContext.sql("Select CONCAT( month_of_death, '-', current_data_year) as date,  total from sf")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql select 358_cause_recode,count("358_cause_recode") from largeTable where manner_of_death IN(2,3) and 358_cause_recode IN (435,
429,
428,
441,
425,
436,
430,
431,
451,
440,
427,
426,
434,
438,
433,
437,
439,
450) group by 358_cause_recode
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select sex,count("358_cause_recode") from largeTable where 358_cause_recode==429  group by sex order by count("358_cause_recode") desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sex</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>M</td><td>184930</td></tr><tr><td>F</td><td>28050</td></tr></tbody></table></div>

# %%
# %sql select age_recode_52,sex,count("358_cause_recode") from largeTable where 358_cause_recode==429  group by age_recode_52,sex order by count("358_cause_recode") desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select race_recode_3,current_data_year,count("358_cause_recode") from largeTable where 358_cause_recode==429 and sex=="M" and age_recode_52>38  group by current_data_year,race_recode_3 order by current_data_year desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql select count("358_cause_recode") from largeTable where 358_cause_recode==435 and place_of_injury_for_causes_w00_y34_except_y06_and_y07_==0
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>49809</td></tr></tbody></table></div>

# %%
# %sql select count("358_cause_recode") from largeTable where 358_cause_recode==435
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>130828</td></tr></tbody></table></div>

# %%
# %sql select sex,count("358_cause_recode") from largeTable where 358_cause_recode IN (420,443)  group by  sex order by count("358_cause_recode") desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sex</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>M</td><td>244154</td></tr><tr><td>F</td><td>138731</td></tr></tbody></table></div>

# %%
# %sql select current_data_year,count("358_cause_recode") from largeTable where 358_cause_recode IN (420,443) and age_recode_52 IN(31,32)  group by current_data_year order by current_data_year desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_data_year</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>2015</td><td>11325</td></tr><tr><td>2014</td><td>9432</td></tr><tr><td>2013</td><td>8367</td></tr><tr><td>2012</td><td>7817</td></tr><tr><td>2011</td><td>7799</td></tr><tr><td>2010</td><td>6917</td></tr><tr><td>2009</td><td>6435</td></tr><tr><td>2008</td><td>6139</td></tr><tr><td>2007</td><td>6083</td></tr><tr><td>2006</td><td>5730</td></tr><tr><td>2005</td><td>4819</td></tr></tbody></table></div>

# %%
# %sql select current_data_year,count("358_cause_recode") from largeTable where 358_cause_recode =429 and marital_status=='M' and age_recode_52 in (35,36,37,38)    group by current_data_year order by current_data_year desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_data_year</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>2015</td><td>3654</td></tr><tr><td>2014</td><td>3735</td></tr><tr><td>2013</td><td>3726</td></tr><tr><td>2012</td><td>3784</td></tr><tr><td>2011</td><td>3589</td></tr><tr><td>2010</td><td>3560</td></tr><tr><td>2009</td><td>3268</td></tr><tr><td>2008</td><td>3262</td></tr><tr><td>2007</td><td>3069</td></tr><tr><td>2006</td><td>2952</td></tr><tr><td>2005</td><td>2895</td></tr></tbody></table></div>

# %%
# %sql select current_data_year,count("358_cause_recode") from largeTable where 358_cause_recode =429  and age_recode_52 in (35,36,37,38)    group by current_data_year order by current_data_year desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_data_year</th><th>count(358_cause_recode)</th></tr></thead><tbody><tr><td>2015</td><td>7852</td></tr><tr><td>2014</td><td>7868</td></tr><tr><td>2013</td><td>7873</td></tr><tr><td>2012</td><td>7865</td></tr><tr><td>2011</td><td>7635</td></tr><tr><td>2010</td><td>7487</td></tr><tr><td>2009</td><td>7172</td></tr><tr><td>2008</td><td>6877</td></tr><tr><td>2007</td><td>6325</td></tr><tr><td>2006</td><td>6047</td></tr><tr><td>2005</td><td>5946</td></tr></tbody></table></div>
